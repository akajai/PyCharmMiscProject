# %%
"""
Tokenizer: program split text into tokens
    Word based: semantic meaning
        NLTKSentenceTokenizer
    Char based: vocabulary is small

    Subword based
        infrequent word are splitted

        UNIGRAM
        SentencePieceTokenizer
        WordPieceTokenizer
        XLNetTokenizer =['_test','_is','end']
        BERTTokenizer
        "<unk>": not in vocabulary


    Tokenizer is a pre-processing step
    NLTKSentenceTokenizer is a post-processing step

Subword-based tokenization allows frequently used words to stay unsplit while breaking down infrequent words.

Using the WordPiece, Unigram, and SentencePiece algorithms, you can implement subword-based tokenization.

You can add special tokens such as <bos> at the beginning and <eos> at the end of a tokenized sentence.


"""
