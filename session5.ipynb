# %%
from pickletools import read_string1

from keras.src.legacy.backend import variable
class Test:
    pass

class Test:
    test1="1"

class Test(object):
    """"thik os a test"""
    learn='test'
    def __init__(self):
        self.learn='Test'  # instance  variable
        self.test='trdyasdasd'
    def tst112(self):
        print('test the function')
t= Test()

print(Test.__doc__)
t.learn
t.tst112()

class Pythonagain(set):

    learn="Python"
    def __init__(self,test,test1,test2):# dunder methords
        self.name=test2
        self.name1=test
#         print("The name of the subject : ",self.name)
obj1=Pythonagain('test',"test1","")
print(obj1.name)
print(obj1.name1)
obj2 = Pythonagain('test',"test1","")
print(obj2.learn)
#Instance variable()
#dir(Pythonagain)
dir(Test)
#self vs cls
# Out:
# "thik os a test
# test the function
#
# test
# Python
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'learn',
#  'tst112']

# %%
class Vehicle:
    def v_info(self):
        print('vinfo')
class Car(Vehicle):
    def car_info(self):
        print('car')

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as pt
from matplotlib import  style as st
print(st.available)
import matplotlib as mpl
# .rc is the function used to configure the global plotting parameters
# figsize is expressed in dots
# dpi means dots per inch
mpl.rc('figure', figsize=(6, 4), dpi=100)
st.use('seaborn-v0_8-deep')
plt.xlabel('Text X')
plt.ylabel('Test Y')
plt.title('Ttile')
plt.plot([1,2,3,4,5],[2,3,45,6,5])
plt.show()
pt.xlabel('Text X')
pt.ylabel('Test Y')
pt.title('Ttile')
x=[1,2,3,4,5];
y=[2,3,45,6,5]
#pt.plot(x,y)
pt.bar(x,y)

pt.savefig('test.jpg')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
from matplotlib.pyplot import  plot
import pandas as pd
pd=pd.read_csv('./Data/random_date_data.csv')
pd
pd.plot()
# Out:
# <Axes: >
