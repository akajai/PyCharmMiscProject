# %% [raw]
# """
# EDA supporting libraries
#
# ydata_profiling
# skimpy
# Sweetviz
# dataprep
#
# """

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import numpy as np
import os
print(os.getcwd())
df = pd.read_csv('CardioGoodFitness.csv', sep=',')

profile = ProfileReport(
    df,
    title="Data Profiling Report",
    explorative=True
)

profile.to_file("report.html")
# Out:
# /Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# /Users/ajaikolarikal/PyCharmMiscProject/EDA/Data
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install skimpy
import pandas as pd

from skimpy import skim

df = pd.read_csv("CardioGoodFitness.csv", sep=",")

skim(df)
# Out:
# ...
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 180    │ │ int64       │ 6     │                                                          │
# │ │ Number of columns │ 9      │ │ string      │ 3     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %%
#!pip install dataprep
import pandas as pd
from dataprep.eda import create_report
from dataprep.eda import plot, plot_correlation, plot_missing


df = pd.read_csv("CardioGoodFitness.csv", sep=",")

create_report(df)

plot(df)
plot_correlation(df)
plot_missing(df)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/bp/zhhmsgsj5wqc3mcx7hb1mkw40000gn/T/ipykernel_25536/664287570.py", line 3, in <module>
#     from dataprep.eda import create_report
#   File "/Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/dataprep/eda/__init__.py", line 8, in <module>
#     from .correlation import compute_correlation, plot_correlation, render_correlation
#   File "/Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/dataprep/eda/correlation/__init__.py", line 10, in <module>
#     from ..configs import Config
#   File "/Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/dataprep/eda/configs.py", line 23, in <module>
# ...

# %% [markdown]
# The user wants to resolve an error in the last cell of the notebook. Looking at the code:
# 1. The file name used in `pd.read_csv("data.csv")` is likely incorrect because the previous cells use `"CardioGoodFitness.csv"` and `data.csv` is not listed in the directory contents.
# 2. The package `dataprep` might have installation issues or version conflicts in some environments, but the immediate error is the `FileNotFoundError` for `data.csv`.
#
# I will provide a corrected version of the logic using the correct file name.

# %%
# !pip install skimpy
# Out:
# ...
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
# Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 6.4 MB/s  0:00:01 eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: pandas━━━━━━━━━━━━━━━━━━ 0/2 [numpy]
#     Found existing installation: pandas 1.5.3 0/2 [numpy]
#     Uninstalling pandas-1.5.3:━━━━━━━━━━━━━━ 0/2 [numpy]
#       Successfully uninstalled pandas-1.5.3━ 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataprep 0.4.5 requires numpy<2.0,>=1.21, but you have numpy 2.0.2 which is incompatible.
# ...

# %%
import pandas as pd
import sweetviz as sv

df = pd.read_csv('CardioGoodFitness.csv', sep=',')

report = sv.analyze(df)
report.show_html("sweetviz_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
