# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="lmstudio-local",
    openai_api_key="no-key",
    openai_api_base="http://localhost:1234/v1"
)

response = llm.invoke("Explain LangChain connecting to LM Studio.")
print(response)
# Out:
# /Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 9
#       1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(
#       4     model="lmstudio-local",
#       5     openai_api_key="no-key",
#       6     openai_api_base="http://localhost:1234/v1"
#       7 )
# ----> 9 response = llm.invoke("Explain LangChain connecting to LM Studio.")
#      10 print(response)
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
# ...
