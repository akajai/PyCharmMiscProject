# %%
"""
one tailed  2 tailed
 1. Probability & Distribution Theory
	•	Moment generating functions (MGF)
	•	Characteristic functions
	•	Law of Large Numbers (LLN)
	•	Central Limit Theorem (CLT) – variants
	•	Joint, marginal, conditional distributions
	•	Copulas (modeling dependency)
	•	Entropy & KL divergence

⸻

🔹 2. Statistical Inference
	•	Score test
	•	Multiple testing correction
	•	Bonferroni
	•	False Discovery Rate (FDR)

⸻

🔹 3. Regression & Modeling
	•	Generalized Linear Models (GLM)
	•	Logistic, Poisson regression
	•	Regularization
	•	Ridge, Lasso, Elastic Net
	•	Multicollinearity & VIF
	•	Bias–variance tradeoff
	•	Heteroscedasticity
	•	Autocorrelation (Durbin–Watson)

⸻

🔹 4. Multivariate Statistics
	•	PCA (Principal Component Analysis)
	•	Factor Analysis
	•	LDA / QDA
	•	MANOVA
	•	Canonical Correlation Analysis
	•	Covariance matrix estimation

⸻

🔹 5. Non-Parametric Statistics
	•	Rank-based tests
	•	Mann–Whitney U
	•	Wilcoxon signed-rank
	•	Kruskal–Wallis
	•	Kernel Density Estimation (KDE)
	•	Bootstrap & permutation tests

⸻

🔹 6. Bayesian Statistics
	•	Bayes theorem (advanced use)
	•	Prior, likelihood, posterior
	•	Conjugate priors
	•	Bayesian inference
	•	MCMC (Markov Chain Monte Carlo)
	•	Gibbs sampling, Metropolis–Hastings
	•	Bayesian hierarchical models

⸻

🔹 7. Time Series Analysis
	•	Stationarity
	•	AR, MA, ARMA, ARIMA
	•	Seasonality & trend decomposition
	•	Autocorrelation (ACF) & Partial ACF
	•	State-space models
	•	Kalman filters

⸻

🔹 8. Causal Inference (VERY IMPORTANT)
	•	Correlation vs causation
	•	Confounding variables
	•	Directed Acyclic Graphs (DAGs)
	•	Randomized Controlled Trials
	•	Propensity score matching
	•	Difference-in-differences
	•	Instru
# Out:
#   Cell In[1], line 82
#     •	Instru
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
gtf
