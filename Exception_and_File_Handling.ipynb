# %% [markdown]
# ## For any programming language there are two types of errors
# 1. Syntax Errors
# 2. Runtime Errors
#
# ### Syntax Error
# The errors which occurs because of invalid syntax, such type of errors are considered as Syntax Errors.
# Programmer is responsible to correct these syntax errors. Once all syntax error are corrected , then only program execution will be started.
#
# ### Runtime Error
# Also Known as Exceptions.
# While executing the program, at runtime if something goes wrong because of the end user input, memory programs, programming logic etc, then we will get Runtime Errors.
# Exception Handling concept applicable for Runtime Errors but not for Syntax Errors.
#
# ### What is an Exception?
# A unexpected unwanted event that distrubs the normal flow of the program is known as Exception
#
# ### What is the main objective of Exception Handling?
# It is highly recommended to handle exceptions.
# The main objective of exception handling in Graceful Termination/Normal Termination of the application(i.e we should not block our resources and we should not miss anything)
#
# ### What is the meaning of Exception Handling?
# Exception handling does not mean repairing an exception. We have to define alternative way to continue rest of the program normally.
# This way of defining alternative solution is nothing but exception handling

# %% [markdown]
# ## Default Exception Handling in Python
#
# Every exception in a python is an object. For every exception type the corresponding class is available.
# Whenver an exception occurs PVM will create the corresponding exception object and will check for handling code. If handling code  available then it will be executed and rest of the program will be executed normally.
# if handling code is not available then PVM will terminates with abnormally and print corresponding exception information to the console. The rest of the program won't get executed
# To prevent this abnormal termination, we should handle exceptions explicitly. Of course by using try-except blocks.
#
# Python's Exception Hierarchy
# Every Exception in python is a class
# AllException classes are child classes of BaseException either directly or indirectly. Hence BaseException acts as root for python Exception Hierarchy.
# Being a programmer, most of the times, we have to concentrate/handle Exception and its child classes.
# root class is BaseException
# 1. Exception
# 2. SystemExit
# 3. GeneratorExit
# 4. KeyboardInterrupt ....
#
#
# In Exception
# 1. ArithmeticError
#      a. ZeroDivisionError
#      b. OverflowError
#      c. FloatingPointError
# 2. LookUpError
#      a. IndexError
#      b. KeyError
# 3. OsError
#      a. FileNotFoundError
#      b. InterruptedError
#      c. TimeOutError
#      d. PermissionError
#
# 4. AttributeError
# 5. EofError
# 6. ValueError
# 7. TypeError
# 8. NameError
#
# ### Control Flow in try -except
# 1. Within the try block if anywhere an exception raised then rest of the try block won't be excecuted even though we handled that exception. Hence isnide try block we have to take only risky code and the length of try block should be as less as possible.
# 2. In addition to try block, there may be a chance of raising exceptions inside except and finally blocks also.
# 3. If anuy statement which not part of try block, raising an exception then it is always Abnormal Termination.
#
#   <pre> Use try except block to handle exceptions
#     try: (risky code)
#     except:(Alternative for risky code)</pre>

# %%
help("Exception")
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      ArithmeticError
#  |      AssertionError
#  |      AttributeError
#  |      BufferError
#  |      ... and 16 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
# ...

# %% [markdown]
# ### Syntax Error

# %%
x=10
if x==10
    print("The value of is  10 ")
# Out:
#   Cell In[10], line 2
#     if x==10
#             ^
# SyntaxError: expected ':'

# %%
print"Hi There"
# Out:
#   Cell In[11], line 1
#     print"Hi There"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
a=apple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a=apple
#
# NameError: name 'apple' is not defined

# %%
PRINT("Hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 PRINT("Hello World")
#
# NameError: name 'PRINT' is not defined

# %%
f=open('xyz.txt')
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 f=open('xyz.txt')
#       2 print(f.read())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz.txt'

# %% [markdown]
# ## Exception

# %%
x=int(input("Enter First number : "))
y=int(input("Enter Second number : "))
print("The Result is : ",x/y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 x=int(input("Enter First number : "))
#       2 y=int(input("Enter Second number : "))
# ----> 3 print("The Result is : ",x/y)
#
# ZeroDivisionError: division by zero

# %%
print("Hello")
print(10/0)
print("Hi")
# Out:
# Hello
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 print("Hello")
# ----> 2 print(10/0)
#       3 print("Hi")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### How to print Exception Information

# %%
try:
    print(10/0)
except ZeroDivisionError as msg:
    print("Exception Type : ", type(msg))
    print("Exception Type : ", msg.__class__)
    print("Exception class name : ", msg.__class__.__name__)
    print("The Description of Exception :",msg)
# Out:
# Exception Type :  <class 'ZeroDivisionError'>
# Exception Type :  <class 'ZeroDivisionError'>
# Exception class name :  ZeroDivisionError
# The Description of Exception : division by zero

# %%
num1=100
num2=0 
try: 
    Quotient =num1/num2
    print("Quotient is : " , Quotient)
except ZeroDivisionError:
    print("Division by Zero is being Performed ")
# Out:
# Division by Zero is being Performed

# %%
num1= 10.9
num2=0 
def performDivision():
    try: 
        Quotient=num1/num2
        print("Quotient is : ", Quotient)
    except NameError:
        print("Name Error Occured")
    # except ZeroDivisionError:
    #     print("Division by zero error Occured")

performDivision()
        
# try: 
#     performDivision()
# except ZeroDivisionError:
#     print("Division by zero is being Performed")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[22], line 12
#       8         print("Name Error Occured")
#       9     # except ZeroDivisionError:
#      10     #     print("Division by zero error Occured")
# ---> 12 performDivision()
#      14 # try:
#      15 #     performDivision()
#      16 # except ZeroDivisionError:
#      17 #     print("Division by zero is being Performed")
#
# Cell In[22], line 5, in performDivision()
#       3 def performDivision():
#       4     try:
# ----> 5         Quotient=num1/num2
#       6         print("Quotient is : ", Quotient)
#       7     except NameError:
#
# ZeroDivisionError: float division by zero

# %%
try: 
    x=30
    
    print(x+"hello")
    print(x/2)

except:
    print("Error Occured")
# Out:
# Error Occured

# %%
try:
    print("Python")
    print(6/0)
except ZeroDivisionError:
    print("Cant divide")
    print(x)
finally:
    print("Hi all this will get printed")

# %%
num1=100 
num2=0
data="Hi"
print(data)
try:
    myList=[1,2,3,4,5,6]
    print(myList[20])
except ZeroDivisionError:
    print("Division by zero is being performed")
except AttributeError:
    print("Attribute Error Occured")
except IndexError:
    print("Index out of range error")

print("No Error line")
# Out:
# Hi
# Index out of range error
# No Error line

# %%
# Manual Exception
x=1

if x<5:
    raise Exception("Number is below 5")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[25], line 5
#       2 x=1
#       4 if x<5:
# ----> 5     raise Exception("Number is below 5")
#
# Exception: Number is below 5

# %%
# To raise an Exception 

def test_exceptions():
    print("Testing AttributeError")
    try:
        raise AttributeError
    except AttributeError:
        print("Attribute error occurred")
        
    print("\nTesting ZeroDivisionError")
    try:
        raise ZeroDivisionError
    except ZeroDivisionError:
        print("Division by zero error occurred")

test_exceptions()

# %%
# User Defined Exception
class BookNotAvailable(Exception):
    pass
class DuplicateBook(Exception):
    pass

def findBook(): 
    print("finding book")
    raise BookNotAvailable
    
def addBook():
    print("Adding Book")
    raise DuplicateBook
    
try:
    findBook()
    addBook()
  
    
except BookNotAvailable:
    print("Book you are trying to find is not available")

except DuplicateBook:
    print("Trying to add a book that is already available")
# Out:
# finding book
# Book you are trying to find is not available

# %%
class BookNotAvailable(Exception):
    def __init__(self, bookId):
        self.bookId= bookId
        
def findBook(bookId):
    print("Finding Book")
    raise BookNotAvailable(bookId)
    
try: 
    findBook(12345)
except BookNotAvailable as e:
    print("Book with Id : {} is not available ".format(e.bookId))
# Out:
# Finding Book
# Book with Id : 12345 is not available

# %%
class BookNotAvailable(Exception):
    def __init__(self, bookId):
        self.bookId= bookId
        
def findBook(bookId):
    print("Finding Book")
    raise BookNotAvailable(bookId)
    
try: 
    findBook(12345)
except BookNotAvailable as e:
    print("Book with Id : {} is not available ".format(e.bookId))

# %%
class duplicate(Exception):
    pass

dic={"Aniket":1,"Yuvra":2,"Suraj":3,"Suhas":5}

def add_roll(roll): 
    try:
        if roll in dic.values():
            raise duplicate
        else:
            name=input("Enter the name of student")
            dic[name]=roll
            print("Roll Number added!")
    except duplicate:
        print("Entered Roll Number is already present")

k=int(input("Enter the rollno: "))

add_roll(k)

print(dic)

# %%
class DuplicateRollNo(Exception):
    pass

class OverflowClass(Exception):
    pass

def add_student(rollno,name):
    try:
        if rollno not in students.keys():
            if len(students)<5:
                students[rollno]=name
            else:
                raise OverflowClass
        else:
            raise DuplicateRollNo
    except DuplicateRollNo:
        print("Roll No. already exists")
    except OverflowClass:
        print("Cant add more than 5 students")
        
students={}
while True:
    if input("Do you want to add a student(Yes-Y | No-N): ").lower()=="y":
        add_student(input("Enter Roll No.: "),input("Enter Name: "))
    else:
        break
# Out:
# Roll No. already exists

# %%
try:
    age=int(input("Enter the age"))
    if age<18:
        raise ValueError
    else:
        print("The age is valid")
except ValueError:
    print("The age is not valid")

# %%
class UnderAge(Exception):
    pass
   # print("Your Underage")

def verify_age(age):
    try:
        
        if int(age) < 18:
            raise UnderAge
            print("Hello There ")
        else:
            print('Age: '+str(age))
            
        print("Addition of 2 and 4 is : " ,(2+4))
    except UnderAge:
        print("The age is less")
            

verify_age(23)  # won't raise exception
print("Hi There ")  
# main program

verify_age(17)  # will raise exception

# %%
def demo_bad_catch():
    try:
        raise ValueError('Represents a hidden bug, do not catch this')
        print(10/0)
        raise ZeroDivisionError('This is the exception you expect to handle')
        
        
    except ZeroDivisionError as error:
        print('Caught this error: ' + repr(error))
    except ValueError as error:
        print("this is an error : " +repr(error))

demo_bad_catch()

# %%
import sys
randomList = ['a', 0, 2]

for entry in randomList:
    try:
        print("The entry is", entry)
        r = 1/int(entry)
        break
    except:
        print("Oops!",sys.exc_info()[0],"occured.") # Here sys.exc_info()[0] provides the errorname
        print("Next entry.")
        print()
print("The reciprocal of",entry,"is",r)

# %%
try:
    fh= open("testfile")
    fh.write("This is my test file for exception handling!!")
except IOError:
    print ("Error: can\'t find file or read data")
else:
    print ("Written content in the file successfully")
    
    fh.close()

# %% [markdown]
# # File Handling

# %% [markdown]
# <pre>
# text, csv, excel, jpeg
# f=open(filename,mode)
# r  read ,rb   read binary , r+ read and write , rb+ read and write binary
# w  write, wb write  binary, w+ write and read, wb+ write and read binary
# a  append  ab append binary a+ append and read  ab+ append and read binary
# x create file
# </pre>

# %%
ls
# Out:
#  Volume in drive C is ACER
#  Volume Serial Number is CE49-E530
#
#  Directory of c:\Users\acer\Desktop\New folder (2)
#
# 11/01/2025  11:41 AM    <DIR>          .
# 11/01/2025  12:22 PM    <DIR>          ..
# 11/01/2025  08:39 AM    <DIR>          classes and objects intro
# 11/01/2025  12:58 PM            47,187 Date and Time , Calendar.ipynb
# 11/01/2025  01:36 PM            40,887 Exception_and_File_Handling.ipynb
# 11/01/2025  12:19 PM            36,808 Functions and Modules.ipynb
# 11/01/2025  07:42 AM    <DIR>          Matplotlib
# 10/30/2025  09:14 AM    <DIR>          Seaborn
# 10/29/2025  07:57 PM               666 session2.ipynb
# 10/26/2025  03:31 PM           216,857 sessions.ipynb
# 11/01/2025  08:32 AM             8,211 tomjerry.jpg
#                6 File(s)        350,616 bytes
#                5 Dir(s)  243,316,924,416 bytes free

# %%
myfile=open("python.txt","w")

# %%
myfile=open("python.txt","a+")

print(myfile)
# Out:
# <_io.TextIOWrapper name='python.txt' mode='a+' encoding='utf-8'>

# %%
# To write in file
myfile=open("python.txt","w")
myfile.write("This file will be written"+"\n")
myfile.write("Hi there")
myfile.close()

print(myfile)
# Out:
# <_io.TextIOWrapper name='python.txt' mode='w' encoding='utf-8'>

# %%
# To read full file
myfile=open("python.txt","r")
tempfile=myfile.read()
print(tempfile)
myfile.close()
# Out:
# This file will be written
# Hi there

# %%
# To read full file
myfile=open("python.txt","r")
tempfile=myfile.read(4)
print(tempfile)
myfile.close()
# Out:
# This

# %%
# using finally Keyword
try:
    f=open("python.txt","r")
    print(f.read())
finally:
    f.close()
# Out:
# This file will be written
# Hi there

# %%
# using with statement 
with open("python.txt","r") as f:
    print(f.read())
# Out:
# This file will be written
# Hi there

# %%
f=open("abc.txt")
print(f.read())
f.close()
# Out:
# Sizing applies to all slides in a presentation
#
# PowerPoint isn't able to resize one slide within a presentation. All slides in a presentation are the same size.
#
# If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See
#
#
# Orientation applies to all slides in a presentation
#
# PowerPoint isn't able to change the page orientation of certain slides. All slides in a presentation have the same page orientation.
#
# If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See
#
#
# See Also
#
#  Change the page orientation in PowerPoint between

# %%
f=open("abc.txt")
print(f.readline())
f.close()
# Out:
# Sizing applies to all slides in a presentation

# %%
f=open("abc.txt")
print(f.readline())
# Out:
# Sizing applies to all slides in a presentation

# %%
print(f.readline())
# Out:
# If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See

# %%
f=open("abc.txt")
text_data=f.readlines()
print(text_data)
f.close()
# Out:
# ['Sizing applies to all slides in a presentation\n', '\n', "PowerPoint isn't able to resize one slide within a presentation. All slides in a presentation are the same size.\n", '\n', 'If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See \n', '\n', '\n', 'Orientation applies to all slides in a presentation\n', '\n', "PowerPoint isn't able to change the page orientation of certain slides. All slides in a presentation have the same page orientation.\n", '\n', 'If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See \n', '\n', '\n', 'See Also\n', '\n', ' Change the page orientation in PowerPoint between \n']

# %%
f=open("abc.txt")
for line in f:
    print(line)
f.close()
# Out:
# Sizing applies to all slides in a presentation
#
#
#
# PowerPoint isn't able to resize one slide within a presentation. All slides in a presentation are the same size.
#
#
#
# If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See
#
#
#
#
#
# Orientation applies to all slides in a presentation
#
#
#
# PowerPoint isn't able to change the page orientation of certain slides. All slides in a presentation have the same page orientation.
#
#
#
# If this is a feature you’d like to request, please send us your feedback to help us prioritize new features in future updates. See
#
#
#
#
#
# See Also
#
#
#
#  Change the page orientation in PowerPoint between

# %%
f=open("abc.txt")
print(f.read(20))

f.close()
# Out:
# Sizing applies to al

# %%
f=open("abc.txt")
print(f.readline(20))

f.close()
# Out:
# Sizing applies to al

# %%
f=open("abc.txt")
for i in range(3):
    print(f.readline(),end="")
f.close()
# Out:
# Sizing applies to all slides in a presentation
#
# PowerPoint isn't able to resize one slide within a presentation. All slides in a presentation are the same size.

# %%
# Writing and appending

# %%
f=open("Apple.txt","w")
f.write("Apples are good to eat \n They are healthy \n An Apple a day keeps Doctor Away")
f.close()

# %%
f=open("Apple.txt")
print(f.read())
f.close()
# Out:
# Apples are good to eat
#  They are healthy
#  An Apple a day keeps Doctor Away

# %%
f=open("Mango.txt","w")
f.write("Mango is King of Fruit \n Now it is Mango Season")
f.close()

# %%
f=open("Mango.txt")
print(f.read())
f.close()
# Out:
# Mango is King of Fruit
#  Now it is Mango Season

# %%
f=open("Mango.txt","w")
f.write("I Like Mangos very much")
f.close()

# %%
f=open("Mango.txt")
print(f.read())
f.close()
# Out:
# I Like Mangos very much

# %%
f=open("Apple.txt","a")
f.write("Apples come in Red and Green Color too")
f.close()

# %%
f=open("Apple.txt")
print(f.read())
f.close()
# Out:
# Apples are good to eat
#  They are healthy
#  An Apple a day keeps Doctor AwayApples come in Red and Green Color too

# %%
f=open("Mango.txt","w")
f.write("I Like Mangos very much")
print(f.read())
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[69], line 3
#       1 f=open("Mango.txt","w")
#       2 f.write("I Like Mangos very much")
# ----> 3 print(f.read())
#       4 f.close()
#
# UnsupportedOperation: not readable

# %%
f=open("Mango.txt","w+")
f.write("I Like Mangos very much")
f.read()
f.close()

# %%
# Create File

# %%
f=open("Hi.txt","w")
f.write("Hello")
f.close()

# %%
# ls

# %%
f=open("Hie.txt","a")
f.write("Hello")
f.close()

# %%
# ls

# %%
f=open("Hie.txt")
print(f.read())
# Out:
# HelloHello

# %%
f=open("Hie.txt","x")
f.write("Hello")
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 f=open("Hie.txt","x")
#       2 f.write("Hello")
#       3 f.close()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'Hie.txt'

# %%
f=open("H.txt","a")
f.write("Hello")
f.close()

# %%
# ls

# %%
f=open("C:\\Users\\acer\\Desktop\\New folder (2)\\tomjerry.jpg","rb")
print(f.read())
f.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00\x94\x00\xcb\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x05\x02\x04\x06\x01\x07\x00\x08\xff\xc4\x00<\x10\x00\x02\x01\x03\x02\x04\x04\x03\x06\x05\x03\x03\x05\x00\x00\x00\x01\x02\x03\x00\x04\x11\x05!\x121AQ\x06\x13aq"2\x81\x14B\x91\xa1\xb1\xd1#Rb\xc1\xf03r\xf1\x15\x16\xe1\x07C\x82\x84\xa2\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x00\x01\x04\x05\x06\x07\xff\xc4\x002\x11\x00\x02\x02\x01\x03\x03\x03\x02\x04\x06\x02\x03\x00\x00\x00\x00\x00\x01\x02\x03\x11\x04\x12!\x051A\x13"Q2a\x06\x14q\xa1#B\x81\x91\xb1\xd13\xf0
# ...

# %%
f=open("C:\\Users\\acer\\Desktop\\New folder (2)\\tomjerry.jpg","ab")
f.write(b"xc1\x8b\x04CN\x96\x81\xbaAW\x14\t\x89\x81\xb9=\x07\xea\xb2\x95}d\x01fM\x87\x17u=\x02Z*Xp\x95\xc1\x12M\xb8^\xeb\x10tG\x12z\x00")
f.close()

# %%
f=open("C:\\Users\\acer\\Desktop\\New folder (2)\\tomjerry.jpg","rb")
print(f.read())
f.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00\x94\x00\xcb\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x05\x02\x04\x06\x01\x07\x00\x08\xff\xc4\x00<\x10\x00\x02\x01\x03\x02\x04\x04\x03\x06\x05\x03\x03\x05\x00\x00\x00\x01\x02\x03\x00\x04\x11\x05!\x121AQ\x06\x13aq"2\x81\x14B\x91\xa1\xb1\xd1#Rb\xc1\xf03r\xf1\x15\x16\xe1\x07C\x82\x84\xa2\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x00\x01\x04\x05\x06\x07\xff\xc4\x002\x11\x00\x02\x02\x01\x03\x03\x03\x02\x04\x06\x02\x03\x00\x00\x00\x00\x00\x01\x02\x03\x11\x04\x12!\x051A\x13"Q2a\x06\x14q\xa1#B\x81\x91\xb1\xd13\xf0
# ...

# %%
f=open("Apple.txt")
pos=f.tell()
print(pos)
# Out:
# 0

# %%
line=f.readline(5)
print(line)
pos1=f.tell()
print(pos1)
# Out:
# Apple
# 5

# %%
f.seek(30)
print(f.read(5))
pos2=f.tell()
print(pos2)
# Out:
#  are
# 35

# %%
f.seek(0)
print(f.read(5))
pos2=f.tell()
print(pos2)

# %%
import time
print(time.asctime())

# %%
import time
f=open("log.txt","a")
for i in range(10):
    f.write(time.asctime())
    time.sleep(2)
f.close()

# %%
f=open("log.txt")
print(f.read())
f.close()
