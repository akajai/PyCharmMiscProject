# %%
"""
https://vitalflux.com/types-probability-distributions-defined-examples/

"""
Discrete Probability Distribution:
    Binomial distribution, which is used to model events with two possible outcomes, such as success and failure
