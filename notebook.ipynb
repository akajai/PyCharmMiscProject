# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
from gettext import install
from numpy.distutils.cpuinfo import cpu
import  calendar
import  math
import random


class Anaimal():
    def __int__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print("bark")

class Dog(Anaimal):
    def bark(self):
        print("Dog")

f=Dog()
f.age=10
print(f.age)
print(f.bark())






def minimum(x,y):
    if x<y:
        return x
    else :
        y

def factorial(n):
    if n==1:
        return 1
    return n* factorial(n-1)

def fib(n):
    if n==1:
        return 0
    if n==2:
        return 1
    else:
        return fib(n-1)+fib(n-2)

print(fib(1))
print(fib(10))
print(fib(20))
print(fib(30))
print(factorial(3))
print(factorial(31))
print(minimum(-9,9))
print(minimum(8.9,9))
#print(math.sqrt(121212))
#print(random.randint(1,20))
n=int(input("enter no"))
print(type(n))
v=['1','2','3','4']
v=[item *2 for i,item in enumerate(v)]
for i,item in enumerate(v):
   v[i]=v[i]*2
for i in range(3,20,3):
    print(i)
t=(v,1)
t2=(1,2,3,4,5)
#t2[3]=6
print(t2[3])
print(v)
print(v[3])
type(v)
print(type(v))
print(random.choice(v))
#print(random.choice(v))
#print(random.choice(v))
random.shuffle(v)
print(v)

print("Hello World!")
s="Hellow test"
print(s[0:len(s)])
print(s[0:3])
#for i in range(5):
 #   print(i)

t=11
while t<10:
    print("While"+t)
    t=t+1

print(t)
print(type(t))
print(type(s))
print(type(1212))
print(type(2+5))
print(type('2+5'))
type('2+5')
#type(1+5)
#n=input("What is ur name")
#print(n)

def square(n):
    return n*n
print(square(3))
def hello():
    print("Hello World!")
hello()
def test(x):
    print("Hello World!")
    s="Hello World!"+str(x)
    print(s)
    print(s[0:len(s)])
    print(s[0:3])

print(square(4))
test(10)
# Out:
# 10
# Dog
# None
# 0
# 34
# 4181
# 514229
# 6
# 8222838654177922817725562880000000
# -9
# 8.9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 59
#      56 print(minimum(8.9,9))
#      57 #print(math.sqrt(121212))
#      58 #print(random.randint(1,20))
# ---> 59 n=int(input("enter no"))
#      60 print(type(n))
#      61 v=['1','2','3','4']
#
# ValueError: invalid literal for int() with base 10: 'sdfsdf'

# %%
print(test(1011))
# Out:
# Hello World!
# Hello World!1011
# Hello World!1011
# Hel
# None
