# %%
from symbol import encoding_decl

from PIL.GimpGradientFile import linear
from keras.src.ops import one_hot
from nbformat.sign import algorithms

#MSE where outliner is there
#Label encoding
nominal one_hot  encoding
ordinal label label encoding

Multi colinearity
U should not have multi colinearity

Keep high varience feature,

tree based algorithm not need feature scalling

decission tree is non  linear algorithms
