# %%
import tensorflow as ts

# %%
help(ts.keras.layers)
# Out:
# Help on package keras._tf_keras.keras.layers in keras._tf_keras.keras:
#
# NAME
#     keras._tf_keras.keras.layers - DO NOT EDIT.
#
# DESCRIPTION
#     This file was autogenerated. Do not edit it by hand,
#     since your modifications would be overwritten.
#
# PACKAGE CONTENTS
#
#
# FILE
#     /Users/ajaikolarikal/PyCharmMiscProject/.venv/lib/python3.9/site-packages/keras/_tf_keras/keras/layers/__init__.py
