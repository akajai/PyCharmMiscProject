# %%
from fontTools.ufoLib import fontInfoOpenTypeHeadFlagsOptions

pwd
ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pwd
#       2 ls
#       3 import os
#
# NameError: name 'pwd' is not defined

# %%
import os
os.getcwd()
os.makedirs('Test11',exist_ok=True)
os.getcwd()
os.chdir('PyCharmMiscProject')

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.9/library/os
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
# ...

# %%
import  random
random.random()
random.randint(1,1012121)
random.randrange(1,200,100)
#help(random)
number=[3,2,1,3,3,4,5,6,]

random.shuffle(number)
print(number)
# Out:
# [6, 2, 3, 3, 4, 5, 3, 1]

# %%
import random

sentence = "Python makes coding fun and creative"
words = sentence.split()
random.shuffle(words)
shuffled_sentence = ' '.join(words)
print(shuffled_sentence)
# Out:
# makes Python fun and creative coding

# %%
import datetime
import calendar
import pytz
from datetime import datetime,timezone
calendar.isleap(2024)
datetime.now(pytz.timezone('Asia/Kolkata'))
# Out:
# datetime.datetime(2025, 11, 1, 13, 0, 51, 986706, tzinfo=<DstTzInfo 'Asia/Kolkata' IST+5:30:00 STD>)

# %%
class BookNotAvailable(Exception):
    pass

class TestIN(Exception):
    def __int__(self,test):

try:
    #0/0
     raise BookNotAvailable
except Exception as e:
    print('error',e)
    print('error',type(e).__name__)
finally:
    print('test completer')
# Out:
# error
# error BookNotAvailable
# test completer

# %%
import os

# Open the file in binary mode
f = open('sample.mp3', 'rb')

# Get the file size
file_size = os.path.getsize('sample.mp3')
print("File size:", file_size, "bytes")

# Read the entire file based on size
data = f.readlines()

# Display a small portion (avoid dumping binary audio data)
print("First 100 bytes:", data[:10000])

f.close()
# Out:
# File size: 28416 bytes
# ...
