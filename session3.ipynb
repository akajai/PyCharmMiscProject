# %%
var1="This Is a test"
#var1.capitalize()
var1.casefold()
var1.casefold()
":".join('test')
sentence = "Hello World Python"
words = sentence.split()  # ['Hello', 'World', 'Python']

# Join them with a different separator
result = "-".join(words)  # 'Hello-World-Python'
print(result)

print(hex(10))
print(bin(12))
print(oct(12))
#var1.swapcase()

for i in range(1,10,3):
    for j in range(i):
        print('*',end='n')
    print()
# Out:
# Hello-World-Python
# 0xa
# 0b1100
# 0o14
# *n
# *n*n*n*n
# *n*n*n*n*n*n*n

# %%
user =input("Enter user ").lower()
userinfo={'jay':'pass','test':'test'}
if user in userinfo.keys():
    pass1=input('Enter password').lower()
    if pass1 in userinfo[user]:
        print('logged in')
    else:
        print('incoreect passwor')
else:
    print('Incorrect user id')
# Out:
# logged in

# %%
#Purchase of 3000 or more put a discount of 10 %
percentage=10
purchases=int(input('Enter  thepur chase'))
if purchases >=3000:
    print('dicount of :',(purchases-3000)*.1)
else:
    print('no discout')
# Out:
# dicount of : 100.0

# %%
def sum(*n):
    result=0
    for i in n:
        result+=i

    return result

print(sum(1,2,3,4,5,6))
# Out:
# 21

# %%
def sum(**n):
    print(n)

print(sum(a=1,b=2,c=3))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# None
