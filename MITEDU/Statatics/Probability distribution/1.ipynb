# %%
"""

Descreate and continious data or distribution
Emperical distribution: data driven  StandardDistribution :Theory driven

The SIR model is a compartmental epidemiological model used to describe how infectious diseases spread in a population.

Compartment Meaning
S
Susceptible (can get infected)
I
Infected (currently infected & contagious)
R
Recovered / Removed (immune or dead)

N = S + I + R

Here is a list of distribution types:

    Bernoulli Distribution
        Head or tail combination
        E(X) = 1*p + 0*(1-p) = p
    Uniform Distribution
        Die
    Binomial Distribution
    Normal or Gaussian Distribution
    Exponential Distribution
    Poisson Distribution

"""

import numpy as np
import statsmodels.api as sm

data = np.random.randn(100)
print(data)
ecdf = sm.distributions.ECDF(data)
print(ecdf)
# Out:
# [ 1.36389985 -0.10646098  0.57782614 -0.25032314  0.419712    1.16013457
#   0.37287889  0.88976699 -1.37323794  0.7490125  -1.84365897 -0.05900341
#  -0.44146455  0.07381241  0.59110072 -0.12483131 -0.82827306 -0.09828682
#   0.41815455  1.11884303 -0.70611646  0.49497182 -0.39100382 -1.71968527
#   0.27089954  0.86623135  0.94390281 -0.43812659  0.79734897  0.73597617
#  -1.13843575  1.36055494  1.55163141  0.41678177 -1.65415091  0.26248625
#  -0.48043855  0.90100581  0.22934016  0.17046772  0.35409573  0.41465806
#  -1.49254788  1.48578896 -1.27537324 -0.81264896  1.1077486  -0.7339555
#   0.23896388 -0.10833768 -0.58474105 -0.5719023   0.6749281  -0.13820944
#  -1.21533988 -0.17190282  1.34683027  0.65627305  2.02446138  0.22442097
#  -0.09008464 -0.54828821  0.75499862 -0.15453571  0.61513505 -1.97435642
#  -0.42992276 -0.01122533 -1.13764469 -0.12218664  0.14256416  0.88817135
#  -1.86306458  0.36396913  1.44586331  0.78911491  0.07441562 -1.32902652
# ...
