# %% [markdown]
# In this activity, you will experiment with three different normalization techniques. Start by generating your random variables within a Pandas dataframe with four columns.

# %%
import pandas as pd
  
# create data
df = pd.DataFrame([
                   [180000, 110, 18.9, 1400], 
                   [360000, 905, 23.4, 1800], 
                   [230000, 230, 14.0, 1300], 
                   [60000, 450, 13.5, 1500]], 
    
                   columns=['Col A', 'Col B',
                            'Col C', 'Col D'])
  
# view data
display(df)
# Out:
#     Col A  Col B  Col C  Col D
# 0  180000    110   18.9   1400
# 1  360000    905   23.4   1800
# 2  230000    230   14.0   1300
# 3   60000    450   13.5   1500

# %% [markdown]
# Explore your data and display the dataframe as a bar graph. As you can see, Col A far outscales the other three columns so that their values look miniscule compared to Col A. This is the motivation towards normalization.

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# Next we will normalize our data frame by using the Max Scaling technique. With Max Scaling we divide each value by the comuln's maximum observed value to get all random varaibles between -1 and 1.

# %%
df_max_scaled = df.copy()
  
# apply normalization techniques
for column in df_max_scaled.columns:
    df_max_scaled[column] = df_max_scaled[column]  / df_max_scaled[column].abs().max()
      
# view normalized data
display(df_max_scaled)
# Out:
#       Col A     Col B     Col C     Col D
# 0  0.500000  0.121547  0.807692  0.777778
# 1  1.000000  1.000000  1.000000  1.000000
# 2  0.638889  0.254144  0.598291  0.722222
# 3  0.166667  0.497238  0.576923  0.833333

# %% [markdown]
# Now display a bar graph of the bar graph of the normalized random variables. Notice how each column is now relative to itself instead of the focus around Column A. This can now allow a model to pick up on features(Columns) which may have been overlooked initially.

# %%
import matplotlib.pyplot as plt

df_max_scaled.plot(kind = 'bar')

# %% [markdown]
# Next we will use Min-Max feature scaling which will normalize the random variables between 0 and 1. This will be achieved by subtracting the minimum feature's value (column value) and then dividing by the feaute's range.

# %%
df_min_max_scaled = df.copy()
  
# apply normalization techniques
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
# view normalized data
print(df_min_max_scaled)
# Out:
#       Col A     Col B     Col C  Col D
# 0  0.400000  0.000000  0.545455    0.2
# 1  1.000000  1.000000  1.000000    1.0
# 2  0.566667  0.150943  0.050505    0.0
# 3  0.000000  0.427673  0.000000    0.4

# %% [markdown]
# Observe the normalization distribution using the min-max scaling technique.

# %%
import matplotlib.pyplot as plt

df_min_max_scaled.plot(kind = 'bar')

# %% [markdown]
# Finally, let's explore a normalization technique known as Standardization. With standadization we will transform the data so each feature has a mean of 0 and deviation of 1.

# %%
# copy the data
df_z_scaled = df.copy()
  
# apply normalization techniques
for column in df_z_scaled.columns:
    df_z_scaled[column] = (df_z_scaled[column] -
                           df_z_scaled[column].mean()) / df_z_scaled[column].std()    
  
# view normalized data   
display(df_z_scaled)
# Out:
#       Col A     Col B     Col C    Col D
# 0 -0.221422 -0.895492  0.311486 -0.46291
# 1  1.227884  1.373564  1.278167  1.38873
# 2  0.181163 -0.552993 -0.741122 -0.92582
# 3 -1.187625  0.074922 -0.848531  0.00000

# %% [markdown]
# Now plot the bar graph of the standardized data to see how it differs from other normalization techniques.

# %%
import matplotlib.pyplot as plt

df_z_scaled.plot(kind='bar')

# %%
"""
In this activity, we explored several normalization techniques such as min-max scaling, z-score standardization, and possibly robust scaling. Each method transformed the data differently depending on its mathematical approach.

The final bar graph of the standardized (z-score) data differed from the other normalization techniques because it centered the data around zero and scaled it based on standard deviation rather than compressing it into a fixed range like 0 to 1. Unlike min-max scaling, which preserves relative spacing within a bounded interval, standardization highlights how far each value deviates from the mean. As a result, the standardized bar graph displayed both positive and negative values, reflecting whether observations were above or below the mean. This makes interpretation relative to overall distribution much clearer, especially when variance matters.

⸻

Workplace Application

In my workplace (technology/software/data environment), normalization would be particularly useful in scenarios where we combine multiple features with different scales. For example:
	•	Comparing customer usage metrics (e.g., session time in minutes vs. number of logins vs. revenue contribution).
	•	Running K-means clustering, where unscaled data would bias results toward larger-scale variables.
	•	Preparing inputs for machine learning models, especially distance-based algorithms like KNN or clustering.

In a past project involving user behavior analytics, features such as “time spent,” “click count,” and “purchase amount” had drastically different ranges. Without normalization, high-value monetary features dominated the clustering output. Applying standardization would have ensured each feature contributed proportionally to the model.

⸻



Going forward, I will:
	•	Use min-max scaling when model inputs require bounded values (e.g., neural networks).
	•	Use z-score standardization for algorithms sensitive to variance (e.g., PCA, clustering).
	•	Consider robust scaling when datasets contain significant outliers.

Normalization is not just preprocessing—it directly influences interpretability and model fairness. Understanding the context and algorithm choice will guide which technique to apply.
"""
