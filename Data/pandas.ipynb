# %% [markdown]
# # Pandas
#
#
# ### It is an Opensource Library
# ### Used to deal with data manipulation and analysis tools using its powerful data structures
#
#
# ### Advantages
# 1. Series : -It is a single dimension data structure with homogenous data types values.
#
# Keyword used is Series()
#
# 2. DataFrame : - It is 2 Dimensional DataFrame is combination of series and can have Heterogenous data type values
#
# Keyword used is DataFrame()
#
# we can handle
#
# Missing data
#
# perform  slice, merge, concatenate, reshape operations

# %%
! pip install pandas numpy

# %%
import pandas as pd
import numpy as np

a=pd.Series([10,20,30])
print(a)

b=pd.Series([10,20,30], index=[1,2,3])#index=["a","b","c"]
print(b)

case=pd.Series([10,20,np.nan])
print(case)

# %%
a=[10,20,30,"Jay"]
print(a)
print(type(a))
b=pd.Series(a)
print(b)
print(type(b))

a=[10,20,30,40,50]
df=pd.DataFrame(a)
print(df)
print(type(df))

# %%
a=[["Jay",89],["Raj",98],["Shlok",100]]
print(a)
print(type(a))
b=pd.DataFrame(a)
print(b)
print(type(b))

# %%
a=[["Jay",89],["Raj",98],["Shlok",100]]
print(a)
print(type(a))
b=pd.DataFrame(a,columns=["Name","Marks"], index=[1,2,3])
print(b)
print(type(b))

print(b["Name"])
r=b["Name"]
print(type(r))
c=b[["Name"]]
print(type(c))

# %%
a={"Name":["Jay","Vijay"],"Age":[35,33]}
print(a)
df=pd.DataFrame(a)
print(df)

# %%
import numpy as np 
a=np.array([[1,2],[3,4]])
print(a)
print(type(a))
b=pd.DataFrame(a)
print(b)
print(type(b))
c=np.array(b)
print(c)
print(type(c))

# %% [markdown]
# ## **Dataframe is most commonly used object in pandas. It is a table like datastructure containing rows and columns similar to excel spreadsheet**

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)
#df = pd.read_csv("weather_data.csv")
df

# %%
import pandas as pd
df1 = pd.read_csv("weather_data.csv")
#print(df1)
df1

# %%
df1.head(10)

# %%
df1.tail(10)

# %%
df1['day']
# df1.day

# %%
df1[['day','event']]

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017']}
df = pd.DataFrame(weather_data)
df

# %%
type(df['day'])

# %%
df1.shape # 
#rows, columns = df.shape

# %%
df1.columns

# %% [markdown]
# ## <font color='blue'>Rows</font>

# %%
#df.head() 
df.head(3)

# %%
df.tail() # df.tail(2)

# %%
df1[1:3]

# %%
df1

# %% [markdown]
# ## <font color='blue'>Columns</font>

# %%
df1.columns

# %%
print(df['day']) # or df.day
print(type(df['day']))

# %%
import pandas as pd
df2= df1[['day','temperature']]
print(df2)

# %%
type(df1[['day','temperature']])

# %% [markdown]
# ## <font color='blue'>Operations On DataFrame</font>

# %%
df2['temperature'].max()

# %%
df2[df2['temperature']>25]

# %%
df2[['day','temperature']][df2['temperature'] == df2['temperature'].min()] # Kinda doing SQL in pandas

# %%
df2[df2['temperature']==df2['temperature'].min()]

# %%
import pandas as pd
df5 = pd.read_csv("weather_data.csv")

# %%
df5
# Out:
#        day      temperature  windspeed event  PlayCricket
# 0   01-01-2017     32.0         6.0      Rain       No
# 1   01-02-2017     35.0         7.0     Sunny      Yes
# 2   01-03-2017     28.0         2.0      Snow       No
# 3   01-04-2017     24.0         7.0      Snow       No
# 4   01-05-2017     32.0         4.0      Rain       No
# 5   01-06-2017     31.0         2.0     Sunny      Yes
# 6   01-07-2017     30.0         0.0      Rain       No
# 7   01-08-2017     29.0        -2.0     Sunny      Yes
# 8   01-09-2017     28.0         NaN      Rain       No
# 9   01-10-2017     27.0         NaN     Sunny      Yes
# 10  01-11-2017     26.0        -8.0      Rain       No
# 11  01-12-2017      NaN       -10.0     Sunny      Yes
# 12  01-01-2018      NaN       -12.0      Rain       No
# 13  01-02-2018     23.0       -14.0     Sunny      Yes
# 14  01-03-2018     22.0       -16.0      Rain       No
# 15  01-04-2018     21.0       -18.0      Rain       No
# ...

# %%
df5[df5['temperature'] == df5['temperature'].max()] # Kinda doing SQL in pandas

# %%
df5['temperature'].std()

# %%
df5['event'].max() # But mean() won't work since data type is string

# %%
df5.describe()
# Out:
#        temperature  windspeed
# count   24.000000   26.000000
# mean    22.291667  -16.307692
# std      7.669699   16.044362
# min      9.000000  -42.000000
# 25%     16.750000  -29.500000
# 50%     22.500000  -17.000000
# 75%     28.250000   -0.500000
# max     35.000000    7.000000

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          28 non-null     object
#  1   temperature  24 non-null     float64
#  2   windspeed    26 non-null     float64
#  3   event        25 non-null     object
#  4   PlayCricket  28 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %% [markdown]
# **Google pandas series operations to find out list of all operations**
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html

# %% [markdown]
# ## <font color='blue'>set_index</font>

# %%
df5 = pd.read_csv("weather_data.csv")

# %%
import pandas as pd

df5.set_index('day')
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 01-01-2017     32.0         6.0      Rain       No
# 01-02-2017     35.0         7.0     Sunny      Yes
# 01-03-2017     28.0         2.0      Snow       No
# 01-04-2017     24.0         7.0      Snow       No
# 01-05-2017     32.0         4.0      Rain       No
# 01-06-2017     31.0         2.0     Sunny      Yes
# 01-07-2017     30.0         0.0      Rain       No
# 01-08-2017     29.0        -2.0     Sunny      Yes
# 01-09-2017     28.0         NaN      Rain       No
# 01-10-2017     27.0         NaN     Sunny      Yes
# 01-11-2017     26.0        -8.0      Rain       No
# 01-12-2017      NaN       -10.0     Sunny      Yes
# 01-01-2018      NaN       -12.0      Rain       No
# 01-02-2018     23.0       -14.0     Sunny      Yes
# 01-03-2018     22.0       -16.0      Rain       No
# 01-04-2018     21.0       -18.0      Rain       No
# 01-05-2018     20.0       -20.0     Sunny      Yes
# ...

# %%
df5
# Out:
#        day      temperature  windspeed event  PlayCricket
# 0   01-01-2017     32.0         6.0      Rain       No
# 1   01-02-2017     35.0         7.0     Sunny      Yes
# 2   01-03-2017     28.0         2.0      Snow       No
# 3   01-04-2017     24.0         7.0      Snow       No
# 4   01-05-2017     32.0         4.0      Rain       No
# 5   01-06-2017     31.0         2.0     Sunny      Yes
# 6   01-07-2017     30.0         0.0      Rain       No
# 7   01-08-2017     29.0        -2.0     Sunny      Yes
# 8   01-09-2017     28.0         NaN      Rain       No
# 9   01-10-2017     27.0         NaN     Sunny      Yes
# 10  01-11-2017     26.0        -8.0      Rain       No
# 11  01-12-2017      NaN       -10.0     Sunny      Yes
# 12  01-01-2018      NaN       -12.0      Rain       No
# 13  01-02-2018     23.0       -14.0     Sunny      Yes
# 14  01-03-2018     22.0       -16.0      Rain       No
# 15  01-04-2018     21.0       -18.0      Rain       No
# ...

# %%
df5.set_index('day', inplace=True)

# %%
df5
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 01-01-2017     32.0         6.0      Rain       No
# 01-02-2017     35.0         7.0     Sunny      Yes
# 01-03-2017     28.0         2.0      Snow       No
# 01-04-2017     24.0         7.0      Snow       No
# 01-05-2017     32.0         4.0      Rain       No
# 01-06-2017     31.0         2.0     Sunny      Yes
# 01-07-2017     30.0         0.0      Rain       No
# 01-08-2017     29.0        -2.0     Sunny      Yes
# 01-09-2017     28.0         NaN      Rain       No
# 01-10-2017     27.0         NaN     Sunny      Yes
# 01-11-2017     26.0        -8.0      Rain       No
# 01-12-2017      NaN       -10.0     Sunny      Yes
# 01-01-2018      NaN       -12.0      Rain       No
# 01-02-2018     23.0       -14.0     Sunny      Yes
# 01-03-2018     22.0       -16.0      Rain       No
# 01-04-2018     21.0       -18.0      Rain       No
# 01-05-2018     20.0       -20.0     Sunny      Yes
# ...

# %%
df5.index
# Out:
# Index(['01-01-2017', '01-02-2017', '01-03-2017', '01-04-2017', '01-05-2017',
#        '01-06-2017', '01-07-2017', '01-08-2017', '01-09-2017', '01-10-2017',
#        '01-11-2017', '01-12-2017', '01-01-2018', '01-02-2018', '01-03-2018',
#        '01-04-2018', '01-05-2018', '01-06-2018', '01-07-2018', '01-08-2018',
#        '01-09-2018', '01-10-2018', '01-11-2018', '01-12-2018', '01-01-2019',
#        '01-02-2019', '01-03-2019', '01-04-2019'],
#       dtype='object', name='day')

# %%
df5.loc['01-02-2017']
# Out:
# temperature     35.0
# windspeed        7.0
# event          Sunny
# PlayCricket      Yes
# Name: 01-02-2017, dtype: object

# %%
df5.iloc[1]
# Out:
# temperature     35.0
# windspeed        7.0
# event          Sunny
# PlayCricket      Yes
# Name: 01-02-2017, dtype: object

# %%
df5.reset_index(inplace=True)
print(df5)

df6=df5[['day','temperature','windspeed','event']]
print(df6)
# Out:
#    event      day      temperature  windspeed PlayCricket
# 0    Rain  01-01-2017     32.0         6.0          No
# 1   Sunny  01-02-2017     35.0         7.0         Yes
# 2    Snow  01-03-2017     28.0         2.0          No
# 3    Snow  01-04-2017     24.0         7.0          No
# 4    Rain  01-05-2017     32.0         4.0          No
# 5   Sunny  01-06-2017     31.0         2.0         Yes
# 6    Rain  01-07-2017     30.0         0.0          No
# 7   Sunny  01-08-2017     29.0        -2.0         Yes
# 8    Rain  01-09-2017     28.0         NaN          No
# 9   Sunny  01-10-2017     27.0         NaN         Yes
# 10   Rain  01-11-2017     26.0        -8.0          No
# 11  Sunny  01-12-2017      NaN       -10.0         Yes
# 12   Rain  01-01-2018      NaN       -12.0          No
# 13  Sunny  01-02-2018     23.0       -14.0         Yes
# 14   Rain  01-03-2018     22.0       -16.0          No
# 15   Rain  01-04-2018     21.0       -18.0          No
# ...

# %%
df5.set_index('day',inplace=True) # this is kind of building a hash map using event as a key
df5
# Out:
#            event   temperature  windspeed PlayCricket
# day
# 01-01-2017   Rain     32.0         6.0          No
# 01-02-2017  Sunny     35.0         7.0         Yes
# 01-03-2017   Snow     28.0         2.0          No
# 01-04-2017   Snow     24.0         7.0          No
# 01-05-2017   Rain     32.0         4.0          No
# 01-06-2017  Sunny     31.0         2.0         Yes
# 01-07-2017   Rain     30.0         0.0          No
# 01-08-2017  Sunny     29.0        -2.0         Yes
# 01-09-2017   Rain     28.0         NaN          No
# 01-10-2017  Sunny     27.0         NaN         Yes
# 01-11-2017   Rain     26.0        -8.0          No
# 01-12-2017  Sunny      NaN       -10.0         Yes
# 01-01-2018   Rain      NaN       -12.0          No
# 01-02-2018  Sunny     23.0       -14.0         Yes
# 01-03-2018   Rain     22.0       -16.0          No
# 01-04-2018   Rain     21.0       -18.0          No
# 01-05-2018  Sunny     20.0       -20.0         Yes
# ...

# %%
df5.loc['Snow']
# Out:
#           day      temperature  windspeed PlayCricket
# event
# Snow   01-03-2017     28.0         2.0         No
# Snow   01-04-2017     24.0         7.0         No

# %% [markdown]
# ## Range Date
#
#
# ### pd.date_range(date,periods,freq)
#
#  freq=frequency in Day(D),Month(M),Year(Y)

# %%
import pandas as pd
import numpy as np

d=pd.date_range("20250415",periods=10, freq="D")
print(d)
# Out:
# DatetimeIndex(['2025-04-15', '2025-04-16', '2025-04-17', '2025-04-18',
#                '2025-04-19', '2025-04-20', '2025-04-21', '2025-04-22',
#                '2025-04-23', '2025-04-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np 
r=np.random.rand(10,4)
print(r)
# Out:
# [[0.6179089  0.60078612 0.61074335 0.70309333]
#  [0.0768889  0.21185788 0.29845118 0.96607054]
#  [0.65761564 0.17408102 0.68175856 0.8410629 ]
#  [0.90005734 0.20796988 0.9475546  0.23176125]
#  [0.15377469 0.63076622 0.03656939 0.7958859 ]
#  [0.142804   0.08649102 0.81897849 0.96326984]
#  [0.76102    0.81945678 0.93688603 0.41384073]
#  [0.31889778 0.7072829  0.62786044 0.68502055]
#  [0.71312979 0.71500563 0.22200462 0.08320396]
#  [0.50040017 0.9401026  0.73447026 0.16447437]]

# %%
df=pd.DataFrame(r)
print(df)
# Out:
#        0         1         2         3
# 0  0.617909  0.600786  0.610743  0.703093
# 1  0.076889  0.211858  0.298451  0.966071
# 2  0.657616  0.174081  0.681759  0.841063
# 3  0.900057  0.207970  0.947555  0.231761
# 4  0.153775  0.630766  0.036569  0.795886
# 5  0.142804  0.086491  0.818978  0.963270
# 6  0.761020  0.819457  0.936886  0.413841
# 7  0.318898  0.707283  0.627860  0.685021
# 8  0.713130  0.715006  0.222005  0.083204
# 9  0.500400  0.940103  0.734470  0.164474

# %%
df=pd.DataFrame(r, index=d,columns=["A","B","C","D"]) #columns=list("ABCD")
print(df)
# Out:
#                 A         B         C         D
# 2025-04-15  0.617909  0.600786  0.610743  0.703093
# 2025-04-16  0.076889  0.211858  0.298451  0.966071
# 2025-04-17  0.657616  0.174081  0.681759  0.841063
# 2025-04-18  0.900057  0.207970  0.947555  0.231761
# 2025-04-19  0.153775  0.630766  0.036569  0.795886
# 2025-04-20  0.142804  0.086491  0.818978  0.963270
# 2025-04-21  0.761020  0.819457  0.936886  0.413841
# 2025-04-22  0.318898  0.707283  0.627860  0.685021
# 2025-04-23  0.713130  0.715006  0.222005  0.083204
# 2025-04-24  0.500400  0.940103  0.734470  0.164474

# %%
print(df.shape)
# Out:
# (10, 4)

# %%
print(df.columns)
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2025-04-15 to 2025-04-24
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       10 non-null     float64
#  1   B       10 non-null     float64
#  2   C       10 non-null     float64
#  3   D       10 non-null     float64
# dtypes: float64(4)
# memory usage: 400.0 bytes
# None

# %%
print(df.describe())
# Out:
#            A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.484250   0.509380   0.591528   0.584768
# std     0.292337   0.308551   0.308841   0.334167
# min     0.076889   0.086491   0.036569   0.083204
# 25%     0.195055   0.208942   0.376524   0.277281
# 50%     0.559155   0.615776   0.654809   0.694057
# 75%     0.699251   0.713075   0.797851   0.829769
# max     0.900057   0.940103   0.947555   0.966071

# %%
df.isnull()
# Out:
#               A      B      C      D
# 2025-04-15  False  False  False  False
# 2025-04-16  False  False  False  False
# 2025-04-17  False  False  False  False
# 2025-04-18  False  False  False  False
# 2025-04-19  False  False  False  False
# 2025-04-20  False  False  False  False
# 2025-04-21  False  False  False  False
# 2025-04-22  False  False  False  False
# 2025-04-23  False  False  False  False
# 2025-04-24  False  False  False  False

# %%
df5
# Out:
#           day      temperature  windspeed PlayCricket
# event
# Rain   01-01-2017     32.0         6.0          No
# Sunny  01-02-2017     35.0         7.0         Yes
# Snow   01-03-2017     28.0         2.0          No
# Snow   01-04-2017     24.0         7.0          No
# Rain   01-05-2017     32.0         4.0          No
# Sunny  01-06-2017     31.0         2.0         Yes
# Rain   01-07-2017     30.0         0.0          No
# Sunny  01-08-2017     29.0        -2.0         Yes
# Rain   01-09-2017     28.0         NaN          No
# Sunny  01-10-2017     27.0         NaN         Yes
# Rain   01-11-2017     26.0        -8.0          No
# Sunny  01-12-2017      NaN       -10.0         Yes
# Rain   01-01-2018      NaN       -12.0          No
# Sunny  01-02-2018     23.0       -14.0         Yes
# Rain   01-03-2018     22.0       -16.0          No
# Rain   01-04-2018     21.0       -18.0          No
# Sunny  01-05-2018     20.0       -20.0         Yes
# ...

# %%
df5.isnull()
# Out:
#             event  temperature  windspeed  PlayCricket
# day
# 01-01-2017  False     False       False       False
# 01-02-2017  False     False       False       False
# 01-03-2017  False     False       False       False
# 01-04-2017  False     False       False       False
# 01-05-2017  False     False       False       False
# 01-06-2017  False     False       False       False
# 01-07-2017  False     False       False       False
# 01-08-2017  False     False       False       False
# 01-09-2017  False     False        True       False
# 01-10-2017  False     False        True       False
# 01-11-2017  False     False       False       False
# 01-12-2017  False      True       False       False
# 01-01-2018  False      True       False       False
# 01-02-2018  False     False       False       False
# 01-03-2018  False     False       False       False
# 01-04-2018  False     False       False       False
# 01-05-2018  False     False       False       False
# ...

# %%
df5.isnull().sum()
# Out:
# event          3
# temperature    4
# windspeed      2
# PlayCricket    0
# dtype: int64

# %%
df6=df5

# %%
df6
# Out:
#            event   temperature  windspeed PlayCricket
# day
# 01-01-2017   Rain     32.0         6.0          No
# 01-02-2017  Sunny     35.0         7.0         Yes
# 01-03-2017   Snow     28.0         2.0          No
# 01-04-2017   Snow     24.0         7.0          No
# 01-05-2017   Rain     32.0         4.0          No
# 01-06-2017  Sunny     31.0         2.0         Yes
# 01-07-2017   Rain     30.0         0.0          No
# 01-08-2017  Sunny     29.0        -2.0         Yes
# 01-09-2017   Rain     28.0         NaN          No
# 01-10-2017  Sunny     27.0         NaN         Yes
# 01-11-2017   Rain     26.0        -8.0          No
# 01-12-2017  Sunny      NaN       -10.0         Yes
# 01-01-2018   Rain      NaN       -12.0          No
# 01-02-2018  Sunny     23.0       -14.0         Yes
# 01-03-2018   Rain     22.0       -16.0          No
# 01-04-2018   Rain     21.0       -18.0          No
# 01-05-2018  Sunny     20.0       -20.0         Yes
# ...

# %%
df6["event"].value_counts()
# Out:
# event
# Rain     13
# Sunny    10
# Snow      2
# Name: count, dtype: int64

# %%
df6
# Out:
#            event   temperature  windspeed PlayCricket
# day
# 01-01-2017   Rain     32.0         6.0          No
# 01-02-2017  Sunny     35.0         7.0         Yes
# 01-03-2017   Snow     28.0         2.0          No
# 01-04-2017   Snow     24.0         7.0          No
# 01-05-2017   Rain     32.0         4.0          No
# 01-06-2017  Sunny     31.0         2.0         Yes
# 01-07-2017   Rain     30.0         0.0          No
# 01-08-2017  Sunny     29.0        -2.0         Yes
# 01-09-2017   Rain     28.0         NaN          No
# 01-10-2017  Sunny     27.0         NaN         Yes
# 01-11-2017   Rain     26.0        -8.0          No
# 01-12-2017  Sunny      NaN       -10.0         Yes
# 01-01-2018   Rain      NaN       -12.0          No
# 01-02-2018  Sunny     23.0       -14.0         Yes
# 01-03-2018   Rain     22.0       -16.0          No
# 01-04-2018   Rain     21.0       -18.0          No
# 01-05-2018  Sunny     20.0       -20.0         Yes
# ...

# %%
df6.dropna() # it will drop the row with missing value 
# df.dropna(axis=0) axis=0 by default it is related to row if axis=1 then it is column
# Out:
#            event   temperature  windspeed PlayCricket
# day
# 01-01-2017   Rain     32.0         6.0          No
# 01-02-2017  Sunny     35.0         7.0         Yes
# 01-03-2017   Snow     28.0         2.0          No
# 01-04-2017   Snow     24.0         7.0          No
# 01-05-2017   Rain     32.0         4.0          No
# 01-06-2017  Sunny     31.0         2.0         Yes
# 01-07-2017   Rain     30.0         0.0          No
# 01-08-2017  Sunny     29.0        -2.0         Yes
# 01-11-2017   Rain     26.0        -8.0          No
# 01-02-2018  Sunny     23.0       -14.0         Yes
# 01-03-2018   Rain     22.0       -16.0          No
# 01-04-2018   Rain     21.0       -18.0          No
# 01-05-2018  Sunny     20.0       -20.0         Yes
# 01-06-2018   Rain     19.0       -22.0          No
# 01-07-2018  Sunny     18.0       -24.0         Yes
# 01-08-2018   Rain     17.0       -26.0          No
# 01-01-2019   Rain     12.0       -36.0          No
# ...

# %%
df6["event"].value_counts()
# Out:
# event
# Rain     13
# Sunny    10
# Snow      2
# Name: count, dtype: int64

# %%
df6.corr(numeric_only=True) # To get correlation
# Out:
#              temperature  windspeed
# temperature   1.000000    0.966556
# windspeed     0.966556    1.000000

# %%
df6.describe(include='all')
# Out:
#        event  temperature  windspeed PlayCricket
# count     25   24.000000   26.000000       28
# unique     3         NaN         NaN        2
# top     Rain         NaN         NaN       No
# freq      13         NaN         NaN       17
# mean     NaN   22.291667  -16.307692      NaN
# std      NaN    7.669699   16.044362      NaN
# min      NaN    9.000000  -42.000000      NaN
# 25%      NaN   16.750000  -29.500000      NaN
# 50%      NaN   22.500000  -17.000000      NaN
# 75%      NaN   28.250000   -0.500000      NaN
# max      NaN   35.000000    7.000000      NaN

# %%
print(df6)
# Out:
#            event   temperature  windspeed PlayCricket
# day
# 01-01-2017   Rain     32.0         6.0          No
# 01-02-2017  Sunny     35.0         7.0         Yes
# 01-03-2017   Snow     28.0         2.0          No
# 01-04-2017   Snow     24.0         7.0          No
# 01-05-2017   Rain     32.0         4.0          No
# 01-06-2017  Sunny     31.0         2.0         Yes
# 01-07-2017   Rain     30.0         0.0          No
# 01-08-2017  Sunny     29.0        -2.0         Yes
# 01-09-2017   Rain     28.0         NaN          No
# 01-10-2017  Sunny     27.0         NaN         Yes
# 01-11-2017   Rain     26.0        -8.0          No
# 01-12-2017  Sunny      NaN       -10.0         Yes
# 01-01-2018   Rain      NaN       -12.0          No
# 01-02-2018  Sunny     23.0       -14.0         Yes
# 01-03-2018   Rain     22.0       -16.0          No
# 01-04-2018   Rain     21.0       -18.0          No
# 01-05-2018  Sunny     20.0       -20.0         Yes
# ...

# %%
df=df6

# %%
print(df["event"])
# Out:
# day
# 01-01-2017     Rain
# 01-02-2017    Sunny
# 01-03-2017     Snow
# 01-04-2017     Snow
# 01-05-2017     Rain
# 01-06-2017    Sunny
# 01-07-2017     Rain
# 01-08-2017    Sunny
# 01-09-2017     Rain
# 01-10-2017    Sunny
# 01-11-2017     Rain
# 01-12-2017    Sunny
# 01-01-2018     Rain
# 01-02-2018    Sunny
# 01-03-2018     Rain
# 01-04-2018     Rain
# 01-05-2018    Sunny
# 01-06-2018     Rain
# 01-07-2018    Sunny
# 01-08-2018     Rain
# 01-09-2018      NaN
# 01-10-2018      NaN
# 01-11-2018      NaN
# 01-12-2018    Sunny
# 01-01-2019     Rain
# 01-02-2019     Rain
# 01-03-2019    Sunny
# 01-04-2019     Rain
# Name: event, dtype: object

# %%
print(df[["A","B"]])
# Out:
#                 A         B
# 2025-04-15  0.617909  0.600786
# 2025-04-16  0.076889  0.211858
# 2025-04-17  0.657616  0.174081
# 2025-04-18  0.900057  0.207970
# 2025-04-19  0.153775  0.630766
# 2025-04-20  0.142804  0.086491
# 2025-04-21  0.761020  0.819457
# 2025-04-22  0.318898  0.707283
# 2025-04-23  0.713130  0.715006
# 2025-04-24  0.500400  0.940103

# %%
print(df["A"][0:3])
# Out:
# 2025-04-15    0.617909
# 2025-04-16    0.076889
# 2025-04-17    0.657616
# Freq: D, Name: A, dtype: float64

# %%
print(df.head(4))
# Out:
#                 A         B         C         D
# 2025-04-15  0.617909  0.600786  0.610743  0.703093
# 2025-04-16  0.076889  0.211858  0.298451  0.966071
# 2025-04-17  0.657616  0.174081  0.681759  0.841063
# 2025-04-18  0.900057  0.207970  0.947555  0.231761

# %%
print(df[0:3])
# Out:
#                 A         B         C         D
# 2025-04-15  0.617909  0.600786  0.610743  0.703093
# 2025-04-16  0.076889  0.211858  0.298451  0.966071
# 2025-04-17  0.657616  0.174081  0.681759  0.841063

# %% [markdown]
# ### df.iloc[row,col]   # By index
#
# ### df.loc[row,col]  # by name
#
#
# loc location when location is needed with respect to index we have to used iloc

# %%
df.iloc[0,0]
# Out:
# 0.6179088993694664

# %%
df.iloc[0,0:2]
# Out:
# A    0.617909
# B    0.600786
# Name: 2025-04-15 00:00:00, dtype: float64

# %%
df.iloc[0:6,0:2]
# Out:
#                 A         B
# 2025-04-15  0.617909  0.600786
# 2025-04-16  0.076889  0.211858
# 2025-04-17  0.657616  0.174081
# 2025-04-18  0.900057  0.207970
# 2025-04-19  0.153775  0.630766
# 2025-04-20  0.142804  0.086491

# %%
df.iloc[0:7:2,0:3]
# Out:
#                 A         B         C
# 2025-04-15  0.617909  0.600786  0.610743
# 2025-04-17  0.657616  0.174081  0.681759
# 2025-04-19  0.153775  0.630766  0.036569
# 2025-04-21  0.761020  0.819457  0.936886

# %%
df.iloc[[0,1,5,6,8],:]
# Out:
#                 A         B         C         D
# 2025-04-15  0.617909  0.600786  0.610743  0.703093
# 2025-04-16  0.076889  0.211858  0.298451  0.966071
# 2025-04-20  0.142804  0.086491  0.818978  0.963270
# 2025-04-21  0.761020  0.819457  0.936886  0.413841
# 2025-04-23  0.713130  0.715006  0.222005  0.083204

# %%
df.iloc[0:7:2,-1:-4:-2]
# Out:
#                 D         B
# 2025-04-15  0.703093  0.600786
# 2025-04-17  0.841063  0.174081
# 2025-04-19  0.795886  0.630766
# 2025-04-21  0.413841  0.819457

# %%
df.iloc[-1:-11:-3,-2::-2]
# Out:
#                 C         A
# 2025-04-24  0.734470  0.500400
# 2025-04-21  0.936886  0.761020
# 2025-04-18  0.947555  0.900057
# 2025-04-15  0.610743  0.617909

# %% [markdown]
# # <font color="purple"><h3 align="center">Different Ways Of Creating Dataframe</h3></font>

# %% [markdown]
# ## <font color="green">Using csv</h3></font>

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")
df
# Out:
#        day      temperature  windspeed event  PlayCricket
# 0   01-01-2017     32.0         6.0      Rain       No
# 1   01-02-2017     35.0         7.0     Sunny      Yes
# 2   01-03-2017     28.0         2.0      Snow       No
# 3   01-04-2017     24.0         7.0      Snow       No
# 4   01-05-2017     32.0         4.0      Rain       No
# 5   01-06-2017     31.0         2.0     Sunny      Yes
# 6   01-07-2017     30.0         0.0      Rain       No
# 7   01-08-2017     29.0        -2.0     Sunny      Yes
# 8   01-09-2017     28.0         NaN      Rain       No
# 9   01-10-2017     27.0         NaN     Sunny      Yes
# 10  01-11-2017     26.0        -8.0      Rain       No
# 11  01-12-2017      NaN       -10.0     Sunny      Yes
# 12  01-01-2018      NaN       -12.0      Rain       No
# 13  01-02-2018     23.0       -14.0     Sunny      Yes
# 14  01-03-2018     22.0       -16.0      Rain       No
# 15  01-04-2018     21.0       -18.0      Rain       No
# ...

# %% [markdown]
# ## <font color="green">Using excel</h3></font>

# %%
df=pd.read_excel("weather_data.xlsx","Sheet1")
df
# Out:
#      day      temperature  windspeed event
# 0 2017-01-01      32           6       Rain
# 1 2017-01-02      35           7      Sunny
# 2 2017-01-03      28           2       Snow

# %% [markdown]
# ## <font color="green">Using dictionary</h3></font>

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#      day     temperature  windspeed event
# 0  1/1/2017      32           6       Rain
# 1  1/2/2017      35           7      Sunny
# 2  1/3/2017      28           2       Snow

# %% [markdown]
# ## <font color="green">Using tuples list</h3></font>

# %%
import pandas as pd
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
#df = pd.DataFrame(weather_data)
#df

df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#      day     temperature  windspeed event
# 0  1/1/2017      32           6       Rain
# 1  1/2/2017      35           7      Sunny
# 2  1/3/2017      28           2       Snow

# %% [markdown]
# ## <font color="green">Using list of dictionaries</h3></font>

# %%
import pandas as pd
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(weather_data)
df

#df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
#df
# Out:
#      day     temperature  windspeed event
# 0  1/1/2017      32           6       Rain
# 1  1/2/2017      35           7      Sunny
# 2  1/3/2017      28           2       Snow

# %% [markdown]
# ## <font color="purple"><h4 align="center">Read/Write CSV and Excel Files in Pandas</font>

# %% [markdown]
# ### <font color="blue">Read CSV</color>

# %%
import pandas as pd

df = pd.read_csv("stock_data.csv")
df
# Out:
#   tickers      eps        revenue price     people
# 0   GOOGL          27.82     87     845     larry page
# 1     WMT           4.61    484      65           n.a.
# 2    MSFT             -1     85      64     bill gates
# 3    RIL   not available     50    1023  mukesh ambani
# 4    TATA            5.6     -1    n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", skiprows=3)
df
# Out:
#    MSFT       -1        85   64    bill gates
# 0  RIL   not available  50  1023  mukesh ambani
# 1  TATA            5.6  -1  n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=3) # skiprows and header are kind of same
df
# Out:
#    MSFT       -1        85   64    bill gates
# 0  RIL   not available  50  1023  mukesh ambani
# 1  TATA            5.6  -1  n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=None, names = ["ticker","eps","revenue","people"])
df
# Out:
#             ticker       eps    revenue     people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv", header=None)
df
# Out:
#      0           1           2       3          4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df = pd.read_csv("stock_data.csv",  nrows=2)
df
# Out:
#   tickers   eps   revenue  price    people
# 0   GOOGL  27.82     87     845   larry page
# 1     WMT   4.61    484      65         n.a.

# %%
df = pd.read_csv("stock_data.csv")
print(df)
print(df.head(2))
# Out:
#   tickers      eps        revenue price     people
# 0   GOOGL          27.82     87     845     larry page
# 1     WMT           4.61    484      65           n.a.
# 2    MSFT             -1     85      64     bill gates
# 3    RIL   not available     50    1023  mukesh ambani
# 4    TATA            5.6     -1    n.a.     ratan tata
#   tickers  eps    revenue price    people
# 0   GOOGL  27.82     87     845  larry page
# 1     WMT   4.61    484      65        n.a.

# %%
df = pd.read_csv("stock_data.csv", na_values=["n.a.", "not available"])
df
# Out:
#   tickers   eps   revenue   price     people
# 0   GOOGL  27.82     87     845.0     larry page
# 1     WMT   4.61    484      65.0            NaN
# 2    MSFT  -1.00     85      64.0     bill gates
# 3    RIL     NaN     50    1023.0  mukesh ambani
# 4    TATA   5.60     -1       NaN     ratan tata

# %%
df = pd.read_csv("stock_data.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'price': ['n.a.'],
        'people': ['not available','n.a.']
    })
df
# Out:
#   tickers   eps   revenue   price     people
# 0   GOOGL  27.82    87.0    845.0     larry page
# 1     WMT   4.61   484.0     65.0            NaN
# 2    MSFT  -1.00    85.0     64.0     bill gates
# 3    RIL     NaN    50.0   1023.0  mukesh ambani
# 4    TATA   5.60     NaN      NaN     ratan tata

# %% [markdown]
# ### <font color="blue">Write to CSV</color>

# %%
df.to_csv("ne.csv",index=False)
df2=pd.read_csv("ne.csv")
df2
# Out:
#   tickers   eps   revenue   price     people
# 0   GOOGL  27.82    87.0    845.0     larry page
# 1     WMT   4.61   484.0     65.0            NaN
# 2    MSFT  -1.00    85.0     64.0     bill gates
# 3    RIL     NaN    50.0   1023.0  mukesh ambani
# 4    TATA   5.60     NaN      NaN     ratan tata

# %%
ls
# Out:
#  Volume in drive C is ACER
#  Volume Serial Number is CE49-E530
#
#  Directory of c:\Users\acer\Desktop\practical_sessions\pandas
#
# 11/15/2025  12:12 PM    <DIR>          .
# 11/09/2025  09:42 AM    <DIR>          ..
# 11/14/2025  04:13 AM               151 A.csv
# 01/11/2020  10:59 AM            11,717 aapl.csv
# 01/11/2020  11:02 AM               535 aapl_no_dates.csv
# 01/11/2020  11:00 AM             1,052 aaplrange.csv
# 11/14/2025  04:13 AM                65 B.csv
# 01/05/2020  09:00 AM            79,728 db_joins.jpg
# 01/11/2020  11:07 AM            48,061 db_tables.jpg
# 01/05/2020  08:58 AM            60,630 group_by_cities.png
# 05/24/2020  04:10 PM             1,700 mtcars.csv
# 11/15/2025  12:12 PM               179 ne.csv
# 04/27/2020  10:51 AM               149 new.csv
# 11/14/2025  04:13 AM             5,190 new.xlsx
# 11/15/2025  12:11 PM               179 new2.csv
# 01/05/2020  08:54 AM             1,368 nyc_weather.csv
# ...

# %%
df2.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
ls
# Out:
#  Volume in drive C is ACER
#  Volume Serial Number is CE49-E530
#
#  Directory of c:\Users\acer\Desktop\practical_sessions\pandas
#
# 11/15/2025  12:12 PM    <DIR>          .
# 11/09/2025  09:42 AM    <DIR>          ..
# 11/14/2025  04:13 AM               151 A.csv
# 01/11/2020  10:59 AM            11,717 aapl.csv
# 01/11/2020  11:02 AM               535 aapl_no_dates.csv
# 01/11/2020  11:00 AM             1,052 aaplrange.csv
# 11/14/2025  04:13 AM                65 B.csv
# 01/05/2020  09:00 AM            79,728 db_joins.jpg
# 01/11/2020  11:07 AM            48,061 db_tables.jpg
# 01/05/2020  08:58 AM            60,630 group_by_cities.png
# 05/24/2020  04:10 PM             1,700 mtcars.csv
# 11/15/2025  12:12 PM               179 ne.csv
# 04/27/2020  10:51 AM               149 new.csv
# 11/14/2025  04:13 AM             5,190 new.xlsx
# 11/15/2025  12:11 PM               179 new2.csv
# 01/05/2020  08:54 AM             1,368 nyc_weather.csv
# ...

# %%
df.to_csv("A.csv",header=False)

# %%
ls

# %%
df.to_csv("B.csv", columns=["tickers","price"], index=False)
df3=pd.read_csv("B.csv")
df3

# %% [markdown]
# ### <font color="blue">Read Excel</color>

# %%
df = pd.read_excel("stock_data.xlsx","Sheet1")
df
# Out:
#   tickers      eps        revenue price     people
# 0   GOOGL          27.82     87     845     larry page
# 1     WMT           4.61    484      65           n.a.
# 2    MSFT             -1     85      64     bill gates
# 3    RIL   not available     50    1023  mukesh ambani
# 4    TATA            5.6     -1    n.a.     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Sam Walton'
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return 50
    return cell
    
df = pd.read_excel("stock_data.xlsx","Sheet1", 
                   converters= {
        'price': convert_people_cell,
        'people': convert_price_cell
    })
df
# Out:
#   tickers      eps        revenue    price        people
# 0   GOOGL          27.82     87           845     larry page
# 1     WMT           4.61    484            65             50
# 2    MSFT             -1     85            64     bill gates
# 3    RIL   not available     50          1023  mukesh ambani
# 4    TATA            5.6     -1    Sam Walton     ratan tata

# %% [markdown]
# ### <font color="blue">Write to Excel</color>

# %%
df.to_excel("new12.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)

# %% [markdown]
# **Write two dataframes to two separate sheets in excel**

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weathers.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')
df

# %%
df['Temperature'].max()

# %%
df['EST'][df['Events']=='Rain']

# %%
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - fillna, interpolate, dropna</font>

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")
print(type(df.day[0]))
df
# Out:
# <class 'str'>
#        day      temperature  windspeed event  PlayCricket
# 0   01-01-2017     32.0         6.0      Rain       No
# 1   01-02-2017     35.0         7.0     Sunny      Yes
# 2   01-03-2017     28.0         2.0      Snow       No
# 3   01-04-2017     24.0         7.0      Snow       No
# 4   01-05-2017     32.0         4.0      Rain       No
# 5   01-06-2017     31.0         2.0     Sunny      Yes
# 6   01-07-2017     30.0         0.0      Rain       No
# 7   01-08-2017     29.0        -2.0     Sunny      Yes
# 8   01-09-2017     28.0         NaN      Rain       No
# 9   01-10-2017     27.0         NaN     Sunny      Yes
# 10  01-11-2017     26.0        -8.0      Rain       No
# 11  01-12-2017      NaN       -10.0     Sunny      Yes
# 12  01-01-2018      NaN       -12.0      Rain       No
# 13  01-02-2018     23.0       -14.0     Sunny      Yes
# 14  01-03-2018     22.0       -16.0      Rain       No
# 15  01-04-2018     21.0       -18.0      Rain       No
# ...

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv",parse_dates=['day'])
print(type(df.day[0]))
df
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#       day      temperature  windspeed event  PlayCricket
# 0  2017-01-01     32.0         6.0      Rain       No
# 1  2017-01-02     35.0         7.0     Sunny      Yes
# 2  2017-01-03     28.0         2.0      Snow       No
# 3  2017-01-04     24.0         7.0      Snow       No
# 4  2017-01-05     32.0         4.0      Rain       No
# 5  2017-01-06     31.0         2.0     Sunny      Yes
# 6  2017-01-07     30.0         0.0      Rain       No
# 7  2017-01-08     29.0        -2.0     Sunny      Yes
# 8  2017-01-09     28.0         NaN      Rain       No
# 9  2017-01-10     27.0         NaN     Sunny      Yes
# 10 2017-01-11     26.0        -8.0      Rain       No
# 11 2017-01-12      NaN       -10.0     Sunny      Yes
# 12 2018-01-01      NaN       -12.0      Rain       No
# 13 2018-01-02     23.0       -14.0     Sunny      Yes
# 14 2018-01-03     22.0       -16.0      Rain       No
# ...

# %%
df.shape
# Out:
# (28, 5)

# %%
import pandas as pd
df1 = pd.read_csv("weather_data.csv")
print(type(df1.day[2]))
df1
# Out:
# <class 'str'>
#        day      temperature  windspeed event  PlayCricket
# 0   01-01-2017     32.0         6.0      Rain       No
# 1   01-02-2017     35.0         7.0     Sunny      Yes
# 2   01-03-2017     28.0         2.0      Snow       No
# 3   01-04-2017     24.0         7.0      Snow       No
# 4   01-05-2017     32.0         4.0      Rain       No
# 5   01-06-2017     31.0         2.0     Sunny      Yes
# 6   01-07-2017     30.0         0.0      Rain       No
# 7   01-08-2017     29.0        -2.0     Sunny      Yes
# 8   01-09-2017     28.0         NaN      Rain       No
# 9   01-10-2017     27.0         NaN     Sunny      Yes
# 10  01-11-2017     26.0        -8.0      Rain       No
# 11  01-12-2017      NaN       -10.0     Sunny      Yes
# 12  01-01-2018      NaN       -12.0      Rain       No
# 13  01-02-2018     23.0       -14.0     Sunny      Yes
# 14  01-03-2018     22.0       -16.0      Rain       No
# 15  01-04-2018     21.0       -18.0      Rain       No
# ...

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         NaN      Rain       No
# 2017-01-10     27.0         NaN     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      NaN       -10.0     Sunny      Yes
# 2018-01-01      NaN       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %% [markdown]
# ## <font color="blue">fillna</font>

# %% [markdown]
# <font color="purple">**Fill all NaN with one specific value**</font>

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         0.0      Rain       No
# 2017-01-10     27.0         0.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      0.0       -10.0     Sunny      Yes
# 2018-01-01      0.0       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %% [markdown]
# <font color="purple">**Fill na using column names and dict**</font>

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'Rain'
    })
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         0.0      Rain       No
# 2017-01-10     27.0         0.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      0.0       -10.0     Sunny      Yes
# 2018-01-01      0.0       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %% [markdown]
# <font color="purple">**Use method to determine how to fill na values**</font>

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0        -2.0      Rain       No
# 2017-01-10     27.0        -2.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12     26.0       -10.0     Sunny      Yes
# 2018-01-01     26.0       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0        -8.0      Rain       No
# 2017-01-10     27.0        -8.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12     23.0       -10.0     Sunny      Yes
# 2018-01-01     23.0       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %% [markdown]
# <font color="purple">**Use of axis**</font>

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
#            temperature windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0    Rain       No
# 2017-01-02     35.0         7.0   Sunny      Yes
# 2017-01-03     28.0         2.0    Snow       No
# 2017-01-04     24.0         7.0    Snow       No
# 2017-01-05     32.0         4.0    Rain       No
# 2017-01-06     31.0         2.0   Sunny      Yes
# 2017-01-07     30.0         0.0    Rain       No
# 2017-01-08     29.0        -2.0   Sunny      Yes
# 2017-01-09     28.0        Rain    Rain       No
# 2017-01-10     27.0       Sunny   Sunny      Yes
# 2017-01-11     26.0        -8.0    Rain       No
# 2017-01-12    -10.0       -10.0   Sunny      Yes
# 2018-01-01    -12.0       -12.0    Rain       No
# 2018-01-02     23.0       -14.0   Sunny      Yes
# 2018-01-03     22.0       -16.0    Rain       No
# 2018-01-04     21.0       -18.0    Rain       No
# 2018-01-05     20.0       -20.0   Sunny      Yes
# 2018-01-06     19.0       -22.0    Rain       No
# ...

# %% [markdown]
# <font color="purple">**limit parameter**</font>

# %%
new_df = df.fillna(method="ffill",limit=2)
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0        -2.0      Rain       No
# 2017-01-10     27.0        -2.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12     26.0       -10.0     Sunny      Yes
# 2018-01-01     26.0       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
new_df1 = df["event"].fillna(method="ffill",limit=2)
new_df1
# Out:
# day
# 2017-01-01     Rain
# 2017-01-02    Sunny
# 2017-01-03     Snow
# 2017-01-04     Snow
# 2017-01-05     Rain
# 2017-01-06    Sunny
# 2017-01-07     Rain
# 2017-01-08    Sunny
# 2017-01-09     Rain
# 2017-01-10    Sunny
# 2017-01-11     Rain
# 2017-01-12    Sunny
# 2018-01-01     Rain
# 2018-01-02    Sunny
# 2018-01-03     Rain
# 2018-01-04     Rain
# 2018-01-05    Sunny
# 2018-01-06     Rain
# 2018-01-07    Sunny
# 2018-01-08     Rain
# 2018-01-09     Rain
# 2018-01-10     Rain
# 2018-01-11      NaN
# 2018-01-12    Sunny
# 2019-01-01     Rain
# 2019-01-02     Rain
# 2019-01-03    Sunny
# 2019-01-04     Rain
# Name: event, dtype: object

# %% [markdown]
# ### <font color="blue">interpolate</font>

# %%
df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         NaN      Rain       No
# 2017-01-10     27.0         NaN     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      NaN       -10.0     Sunny      Yes
# 2018-01-01      NaN       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
new_df = df.interpolate()
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0        -4.0      Rain       No
# 2017-01-10     27.0        -6.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12     25.0       -10.0     Sunny      Yes
# 2018-01-01     24.0       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
new_df = df.interpolate(method="time") 
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01   32.000000      6.0      Rain       No
# 2017-01-02   35.000000      7.0     Sunny      Yes
# 2017-01-03   28.000000      2.0      Snow       No
# 2017-01-04   24.000000      7.0      Snow       No
# 2017-01-05   32.000000      4.0      Rain       No
# 2017-01-06   31.000000      2.0     Sunny      Yes
# 2017-01-07   30.000000      0.0      Rain       No
# 2017-01-08   29.000000     -2.0     Sunny      Yes
# 2017-01-09   28.000000     -4.0      Rain       No
# 2017-01-10   27.000000     -6.0     Sunny      Yes
# 2017-01-11   26.000000     -8.0      Rain       No
# 2017-01-12   25.991573    -10.0     Sunny      Yes
# 2018-01-01   23.008427    -12.0      Rain       No
# 2018-01-02   23.000000    -14.0     Sunny      Yes
# 2018-01-03   22.000000    -16.0      Rain       No
# 2018-01-04   21.000000    -18.0      Rain       No
# 2018-01-05   20.000000    -20.0     Sunny      Yes
# ...

# %% [markdown]
# **Notice that in above temperature on 2017-01-04 is 29 instead of 30 (in plain linear interpolate)**

# %% [markdown]
# **There are many other methods for interpolation such as quadratic, piecewise_polynomial, cubic etc.
# Just google "dataframe interpolate" to see complete documentation**

# %%
help(pd.DataFrame.interpolate)
# Out:
# Help on function interpolate in module pandas.core.generic:
#
# interpolate(self, method: 'InterpolateOptions' = 'linear', *, axis: 'Axis' = 0, limit: 'int | None' = None, inplace: 'bool_t' = False, limit_direction: "Literal['forward', 'backward', 'both'] | None" = None, limit_area: "Literal['inside', 'outside'] | None" = None, downcast: "Literal['infer'] | None | lib.NoDefault" = <no_default>, **kwargs) -> 'Self | None'
#     Fill NaN values using an interpolation method.
#
#     Please note that only ``method='linear'`` is supported for
#     DataFrame/Series with a MultiIndex.
#
#     Parameters
#     ----------
#     method : str, default 'linear'
#         Interpolation technique to use. One of:
#
#         * 'linear': Ignore the index and treat the values as equally
#           spaced. This is the only method supported on MultiIndexes.
#         * 'time': Works on daily and higher resolution data to interpolate
#           given length of interval.
# ...

# %% [markdown]
# ### <font color="blue">dropna</font>

# %%
df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         NaN      Rain       No
# 2017-01-10     27.0         NaN     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      NaN       -10.0     Sunny      Yes
# 2018-01-01      NaN       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
df['temperature'].mean()
# Out:
# 22.291666666666668

# %%
df['temperature'].median()
# Out:
# 22.5

# %%
df.fillna(df['temperature'].mean())
# Out:
#             temperature  windspeed   event    PlayCricket
# day
# 2017-01-01   32.000000    6.000000       Rain       No
# 2017-01-02   35.000000    7.000000      Sunny      Yes
# 2017-01-03   28.000000    2.000000       Snow       No
# 2017-01-04   24.000000    7.000000       Snow       No
# 2017-01-05   32.000000    4.000000       Rain       No
# 2017-01-06   31.000000    2.000000      Sunny      Yes
# 2017-01-07   30.000000    0.000000       Rain       No
# 2017-01-08   29.000000   -2.000000      Sunny      Yes
# 2017-01-09   28.000000   22.291667       Rain       No
# 2017-01-10   27.000000   22.291667      Sunny      Yes
# 2017-01-11   26.000000   -8.000000       Rain       No
# 2017-01-12   22.291667  -10.000000      Sunny      Yes
# 2018-01-01   22.291667  -12.000000       Rain       No
# 2018-01-02   23.000000  -14.000000      Sunny      Yes
# 2018-01-03   22.000000  -16.000000       Rain       No
# 2018-01-04   21.000000  -18.000000       Rain       No
# ...

# %%
df.shape
# Out:
# (28, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 28 entries, 2017-01-01 to 2019-01-04
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  24 non-null     float64
#  1   windspeed    26 non-null     float64
#  2   event        25 non-null     object
#  3   PlayCricket  28 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.1+ KB

# %%
df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         NaN      Rain       No
# 2017-01-10     27.0         NaN     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      NaN       -10.0     Sunny      Yes
# 2018-01-01      NaN       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
new=df.dropna(axis=1)
new
# Out:
#            PlayCricket
# day
# 2017-01-01       No
# 2017-01-02      Yes
# 2017-01-03       No
# 2017-01-04       No
# 2017-01-05       No
# 2017-01-06      Yes
# 2017-01-07       No
# 2017-01-08      Yes
# 2017-01-09       No
# 2017-01-10      Yes
# 2017-01-11       No
# 2017-01-12      Yes
# 2018-01-01       No
# 2018-01-02      Yes
# 2018-01-03       No
# 2018-01-04       No
# 2018-01-05      Yes
# 2018-01-06       No
# 2018-01-07      Yes
# 2018-01-08       No
# 2018-01-09       No
# 2018-01-10      Yes
# 2018-01-11       No
# 2018-01-12      Yes
# 2019-01-01       No
# 2019-01-02       No
# 2019-01-03      Yes
# 2019-01-04       No

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# 2018-01-06     19.0       -22.0      Rain       No
# 2018-01-07     18.0       -24.0     Sunny      Yes
# 2018-01-08     17.0       -26.0      Rain       No
# 2019-01-01     12.0       -36.0      Rain       No
# ...

# %%
new_df.shape
# Out:
# (20, 4)

# %%
new_df = df.dropna(how='all')
new_df

#any’ : If any NA values are present, drop that row or column.
#‘all’ : If all values are NA, drop that row or column.
#thresh : int, optional
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-09     28.0         NaN      Rain       No
# 2017-01-10     27.0         NaN     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2017-01-12      NaN       -10.0     Sunny      Yes
# 2018-01-01      NaN       -12.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# ...

# %%
new_df = df.dropna(thresh=4)
new_df
# Out:
#             temperature  windspeed event  PlayCricket
# day
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# 2017-01-06     31.0         2.0     Sunny      Yes
# 2017-01-07     30.0         0.0      Rain       No
# 2017-01-08     29.0        -2.0     Sunny      Yes
# 2017-01-11     26.0        -8.0      Rain       No
# 2018-01-02     23.0       -14.0     Sunny      Yes
# 2018-01-03     22.0       -16.0      Rain       No
# 2018-01-04     21.0       -18.0      Rain       No
# 2018-01-05     20.0       -20.0     Sunny      Yes
# 2018-01-06     19.0       -22.0      Rain       No
# 2018-01-07     18.0       -24.0     Sunny      Yes
# 2018-01-08     17.0       -26.0      Rain       No
# 2019-01-01     12.0       -36.0      Rain       No
# ...

# %% [markdown]
# ### <font color="blue">Inserting Missing Dates</font>

# %%
dt = pd.date_range("01-01-2017","04-01-2019")
print(dt)
idx = pd.DatetimeIndex(dt)
print(type(idx))
df.reindex(idx)
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2019-03-23', '2019-03-24', '2019-03-25', '2019-03-26',
#                '2019-03-27', '2019-03-28', '2019-03-29', '2019-03-30',
#                '2019-03-31', '2019-04-01'],
#               dtype='datetime64[ns]', length=821, freq='D')
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#             temperature  windspeed event  PlayCricket
# 2017-01-01     32.0         6.0      Rain       No
# 2017-01-02     35.0         7.0     Sunny      Yes
# 2017-01-03     28.0         2.0      Snow       No
# 2017-01-04     24.0         7.0      Snow       No
# 2017-01-05     32.0         4.0      Rain       No
# ...                 ...        ...    ...         ...
# 2019-03-28      NaN         NaN       NaN      NaN
# ...

# %%
help(df.fillna)

# %% [markdown]
# # <font color="purple"><h3 align="center">Pandas Concatenate Tutorial</h3></font>

# %% [markdown]
# ## <font color='blue'>Basic Concatenation</font>

# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#      city    temperature  humidity
# 0    mumbai      32          80
# 1     delhi      45          60
# 2  banglore      30          78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#      city    temperature  humidity
# 0  new york      21          68
# 1   chicago      14          65
# 2   orlando      35          75

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#      city    temperature  humidity
# 0    mumbai      32          80
# 1     delhi      45          60
# 2  banglore      30          78
# 0  new york      21          68
# 1   chicago      14          65
# 2   orlando      35          75

# %% [markdown]
# ## <font color='blue'>Ignore Index</font>

# %%
df = pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#      city    temperature  humidity
# 0    mumbai      32          80
# 1     delhi      45          60
# 2  banglore      30          78
# 3  new york      21          68
# 4   chicago      14          65
# 5   orlando      35          75

# %%
df5 = pd.concat([india_weather, us_weather], ignore_index=True)
df5
# Out:
#      city    temperature  humidity
# 0    mumbai      32          80
# 1     delhi      45          60
# 2  banglore      30          78
# 3  new york      21          68
# 4   chicago      14          65
# 5   orlando      35          75

# %% [markdown]
# ## <font color='blue'>Concatenation And Keys</font>

# %%
import pandas as pd
df = pd.concat([india_weather, us_weather], keys=["india", "us"])
print(df)
# Out:
#            city    temperature  humidity
# india 0    mumbai      32          80
#       1     delhi      45          60
#       2  banglore      30          78
# us    0  new york      21          68
#       1   chicago      14          65
#       2   orlando      35          75

# %%
df.loc["us"]
# Out:
#      city    temperature  humidity
# 0  new york      21          68
# 1   chicago      14          65
# 2   orlando      35          75

# %%
df.loc["india"]
# Out:
#      city    temperature  humidity
# 0    mumbai      32          80
# 1     delhi      45          60
# 2  banglore      30          78

# %% [markdown]
# ## <font color='blue'>Concatenation Using Index</font>

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#      city    temperature
# 0    mumbai      32
# 1     delhi      45
# 2  banglore      30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[3,4])
windspeed_df
# Out:
#     city   windspeed
# 3   delhi      7
# 4  mumbai     12

# %%
df = pd.concat([temperature_df,windspeed_df,],axis=0)
df
# Out:
#      city    temperature  windspeed
# 0    mumbai     32.0         NaN
# 1     delhi     45.0         NaN
# 2  banglore     30.0         NaN
# 3     delhi      NaN         7.0
# 4    mumbai      NaN        12.0

# %% [markdown]
# ## <font color='blue'>Concatenate dataframe with series</font>

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df,s],axis=1)
df
# Out:
#      city    temperature event
# 0    mumbai      32       Humid
# 1     delhi      45         Dry
# 2  banglore      30        Rain

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - replace method</font>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("weareplace_data.csv")
df
# Out:
#       day     temperature windspeed event   dayno
# 0  01-01-2017      32 C      6kmph    Rain      1
# 1  01-02-2017    -99999          7   Sunny      2
# 2  01-03-2017        28     -99999    Snow      3
# 3  01-04-2017    -99999          7       0 -99999
# 4  01-05-2017        32     -99999    Rain      4
# 5  01-06-2017        31          2   Sunny      5
# 6  01-06-2017      34 C      5kmph       0      6

# %%
import pandas as pd
type(df.temperature[4])
# Out:
# str

# %% [markdown]
# **Replacing single value**

# %%
#print(df)
new = df.replace(-99999, value=np.NaN)
new
# Out:
#       day     temperature windspeed event   dayno
# 0  01-01-2017      32 C      6kmph    Rain   1.0
# 1  01-02-2017    -99999          7   Sunny   2.0
# 2  01-03-2017        28     -99999    Snow   3.0
# 3  01-04-2017    -99999          7       0   NaN
# 4  01-05-2017        32     -99999    Rain   4.0
# 5  01-06-2017        31          2   Sunny   5.0
# 6  01-06-2017      34 C      5kmph       0   6.0

# %% [markdown]
# **Replacing list with single value**

# %%
new_df = df.replace(to_replace=["-99999","-88888",-99999], value=0)
new_df
# Out:
#       day     temperature windspeed event   dayno
# 0  01-01-2017     32 C       6kmph    Rain    1
# 1  01-02-2017        0           7   Sunny    2
# 2  01-03-2017       28           0    Snow    3
# 3  01-04-2017        0           7       0    0
# 4  01-05-2017       32           0    Rain    4
# 5  01-06-2017       31           2   Sunny    5
# 6  01-06-2017     34 C       5kmph       0    6

# %%
new_df1 = new_df.replace({
        "-99999": np.nan,
        0: 'Sunny',
    })
new_df1
# Out:
#       day     temperature windspeed event  dayno
# 0  01-01-2017      32 C      6kmph    Rain      1
# 1  01-02-2017     Sunny          7   Sunny      2
# 2  01-03-2017        28      Sunny    Snow      3
# 3  01-04-2017     Sunny          7       0  Sunny
# 4  01-05-2017        32      Sunny    Rain      4
# 5  01-06-2017        31          2   Sunny      5
# 6  01-06-2017      34 C      5kmph       0      6

# %% [markdown]
# **Replacing per column**

# %%
new_df = df.replace({
        'temperature': '-99999',
        'windspeed': '-99999',
        'event': '0'
    }, np.NaN)
new_df
# Out:
#       day     temperature windspeed event   dayno
# 0  01-01-2017     32 C       6kmph    Rain      1
# 1  01-02-2017      NaN           7   Sunny      2
# 2  01-03-2017       28         NaN    Snow      3
# 3  01-04-2017      NaN           7     NaN -99999
# 4  01-05-2017       32         NaN    Rain      4
# 5  01-06-2017       31           2   Sunny      5
# 6  01-06-2017     34 C       5kmph     NaN      6

# %% [markdown]
# **Replacing by using mapping**

# %%
new_df = df.replace({
        "-99999": np.nan,
        '0': 'Sunny',
    })
new_df
# Out:
#       day     temperature windspeed event   dayno
# 0  01-01-2017     32 C       6kmph    Rain      1
# 1  01-02-2017      NaN           7   Sunny      2
# 2  01-03-2017       28         NaN    Snow      3
# 3  01-04-2017      NaN           7   Sunny -99999
# 4  01-05-2017       32         NaN    Rain      4
# 5  01-06-2017       31           2   Sunny      5
# 6  01-06-2017     34 C       5kmph   Sunny      6

# %% [markdown]
# **Regex**

# %%
# when windspeed is 6 mph, 7 mph etc. & temperature is 32 F, 28 F etc.
new_df = df.replace({'temperature': '[A-Za-z]', 'windspeed': '[A-Za-z]'},'', regex=True) 
new_df
# Out:
#       day     temperature windspeed event   dayno
# 0  01-01-2017       32           6    Rain      1
# 1  01-02-2017    -99999          7   Sunny      2
# 2  01-03-2017        28     -99999    Snow      3
# 3  01-04-2017    -99999          7       0 -99999
# 4  01-05-2017        32     -99999    Rain      4
# 5  01-06-2017        31          2   Sunny      5
# 6  01-06-2017       34           5       0      6

# %%
type(new_df['temperature'][0])
# Out:
# str

# %% [markdown]
# **Replacing list with another list** <br>
#
# **One way to deal with Categorical data**

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#      score     student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
#    score student
# 0    4        rob
# 1    2       maya
# 2    3    parthiv
# 3    1        tom
# 4    2     julian
# 5    4      erica

# %% [markdown]
# ## <font color="maroon"><h4 align="center">Pandas Group By</font>

# %% [markdown]
# **In this tutorial we are going to look at weather data from various cities and see how group by can be used to run some analytics.**

# %%
import pandas as pd
df = pd.read_csv("weather_by_cities.csv")
df
# Out:
#        day        city    temperature  windspeed  event
# 0   01-01-2017  new york      32           6        Rain
# 1   01-02-2017  new york      36           7       Sunny
# 2   01-03-2017  new york      28          12        Snow
# 3   01-04-2017  new york      33           7       Sunny
# 4   01-01-2017    mumbai      90           5       Sunny
# 5   01-02-2017    mumbai      85          12         Fog
# 6   01-03-2017    mumbai      87          15         Fog
# 7   01-04-2017    mumbai      92           5        Rain
# 8   01-01-2017     paris      45          20       Sunny
# 9   01-02-2017     paris      50          13      Cloudy
# 10  01-03-2017     paris      54           8      Cloudy
# 11  01-04-2017     paris      42          10      Cloudy

# %%
print(df.describe())
# Out:
#        temperature  windspeed
# count   12.000000   12.000000
# mean    56.166667   10.000000
# std     25.044808    4.572646
# min     28.000000    5.000000
# 25%     35.250000    6.750000
# 50%     47.500000    9.000000
# 75%     85.500000   12.250000
# max     92.000000   20.000000

# %% [markdown]
# ### For this dataset, get following answers,
# #### 1. What was the maximum temperature in each of these 3 cities?
# #### 2. What was the average windspeed in each of these 3 cities?

# %%
g = df.groupby("city")
print(g)

# %% [markdown]
# **DataFrameGroupBy object looks something like below,**

# %% [markdown]
# <img src="group_by_cities.png">

# %%
for city, data in g:
    print("city:",city)
    print( )
    print("data:",data)
# Out:
# city: mumbai
#
# data:       day       city   temperature  windspeed event
# 4  01-01-2017  mumbai      90           5      Sunny
# 5  01-02-2017  mumbai      85          12        Fog
# 6  01-03-2017  mumbai      87          15        Fog
# 7  01-04-2017  mumbai      92           5       Rain
# city: new york
#
# data:       day        city    temperature  windspeed event
# 0  01-01-2017  new york      32           6       Rain
# 1  01-02-2017  new york      36           7      Sunny
# 2  01-03-2017  new york      28          12       Snow
# 3  01-04-2017  new york      33           7      Sunny
# city: paris
#
# data:        day      city   temperature  windspeed  event
# 8   01-01-2017  paris      45          20       Sunny
# 9   01-02-2017  paris      50          13      Cloudy
# 10  01-03-2017  paris      54           8      Cloudy
# 11  01-04-2017  paris      42          10      Cloudy

# %% [markdown]
# **This is similar to SQL,**
#
# **SELECT * from weather_data GROUP BY city**

# %%
g.get_group('mumbai')
# Out:
#       day       city   temperature  windspeed event
# 4  01-01-2017  mumbai      90           5      Sunny
# 5  01-02-2017  mumbai      85          12        Fog
# 6  01-03-2017  mumbai      87          15        Fog
# 7  01-04-2017  mumbai      92           5       Rain

# %%
g.max()
# Out:
#              day      temperature  windspeed event
# city
# mumbai    01-04-2017      92          15      Sunny
# new york  01-04-2017      36          12      Sunny
# paris     01-04-2017      54          20      Sunny

# %%
g.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\acer\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File c:\Users\acer\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\acer\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %% [markdown]
# **This method of splitting your dataset in smaller groups and then applying an operation
# (such as min or max) to get aggregate result is called Split-Apply-Combine. It is illustrated in a diagram below**

# %% [markdown]
# <img src="split_apply_combine.png">

# %%
g.min()
# Out:
#              day      temperature  windspeed  event
# city
# mumbai    01-01-2017      85           5         Fog
# new york  01-01-2017      28           6        Rain
# paris     01-01-2017      42           8      Cloudy

# %%
b= g.describe()
b
# Out:
#          temperature                                                   \
#             count     mean     std     min   25%    50%   75%    max
# city
# mumbai        4.0     88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york      4.0     32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris         4.0     47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#            count    mean     std    min   25%   50%   75%    max
# city
# mumbai       4.0     9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york     4.0     8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris        4.0    12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
b.T
# Out:
# city                mumbai    new york     paris
# temperature count   4.000000   4.000000   4.000000
#             mean   88.500000  32.250000  47.750000
#             std     3.109126   3.304038   5.315073
#             min    85.000000  28.000000  42.000000
#             25%    86.500000  31.000000  44.250000
#             50%    88.500000  32.500000  47.500000
#             75%    90.500000  33.750000  51.000000
#             max    92.000000  36.000000  54.000000
# windspeed   count   4.000000   4.000000   4.000000
#             mean    9.250000   8.000000  12.750000
#             std     5.057997   2.708013   5.251984
#             min     5.000000   6.000000   8.000000
#             25%     5.000000   6.750000   9.500000
#             50%     8.500000   7.000000  11.500000
#             75%    12.750000   8.250000  14.750000
#             max    15.000000  12.000000  20.000000

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai     4        4           4        4
# new york   4        4           4        4
# paris      4        4           4        4

# %%
help(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 help(plot)
#
# NameError: name 'plot' is not defined

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      Axes(0.08,0.07;0.87x0.81)
# new york    Axes(0.08,0.07;0.87x0.81)
# paris       Axes(0.08,0.07;0.87x0.81)
# dtype: object

# %% [markdown]
# <h4>Group data using custom function: Let's say you want to group your data using custom function. Here the requirement is to create three groups<h4>
# <ol>
#     <li>Days when temperature was between 80 and 90</li>
#     <li>Days when it was between 50 and 60</li>
#     <li>Days when it was anything else</li>
# </ol>

# %% [markdown]
# For this you need to write custom grouping function and pass that to groupby

# %%
def grouper(df, idx, col):
    if 80 <= df[col].loc[idx] <= 90:
        return '80-90'
    elif 50 <= df[col].loc[idx] <= 60:
        return '50-60'
    else:
        return 'others'

# %%
g = df.groupby(lambda x: grouper(df, x, 'temperature'))
print(g)

# %%
for key, d in g:
    print("Group by Key: {}\n".format(key))
    print(d)
# Out:
# Group by Key: 50-60
#
#        day      city   temperature  windspeed  event
# 9   01-02-2017  paris      50          13      Cloudy
# 10  01-03-2017  paris      54           8      Cloudy
# Group by Key: 80-90
#
#       day       city   temperature  windspeed event
# 4  01-01-2017  mumbai      90           5      Sunny
# 5  01-02-2017  mumbai      85          12        Fog
# 6  01-03-2017  mumbai      87          15        Fog
# Group by Key: others
#
#        day        city    temperature  windspeed  event
# 0   01-01-2017  new york      32           6        Rain
# 1   01-02-2017  new york      36           7       Sunny
# 2   01-03-2017  new york      28          12        Snow
# 3   01-04-2017  new york      33           7       Sunny
# 7   01-04-2017    mumbai      92           5        Rain
# 8   01-01-2017     paris      45          20       Sunny
# 11  01-04-2017     paris      42          10      Cloudy

# %% [markdown]
# # <font color="purple"><h3 align="center">Pandas Merge Tutorial</h3></font>

# %% [markdown]
# ## <font color='blue'>Basic Merge Using a Dataframe Column</font>

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando","WDC"],
    "temperature": [21,14,35,45],
})
df1
# Out:
#      city    temperature
# 0  new york      21
# 1   chicago      14
# 2   orlando      35
# 3       WDC      45

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando","new york"],
    "humidity": [65,68,75,70],
})
df2
# Out:
#      city    humidity
# 0   chicago     65
# 1  new york     68
# 2   orlando     75
# 3  new york     70

# %%
df3 = pd.merge(df2, df1, on="city")
df3
# Out:
#      city    humidity  temperature
# 0   chicago     65         14
# 1  new york     68         21
# 2   orlando     75         35
# 3  new york     70         21

# %% [markdown]
# ## <font color='blue'>Type Of DataBase Joins</font>

# %% [markdown]
# <img src="db_joins.jpg" height="800", width="800">

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#      city     temperature
# 0   new york      21
# 1    chicago      14
# 2    orlando      35
# 3  baltimore      38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#      city     humidity
# 0    chicago     65
# 1   new york     68
# 2  san diego     71

# %%
df3=pd.merge(df1,df2,on="city",how="inner")
df3
# Out:
#      city    temperature  humidity
# 0  new york      21          68
# 1   chicago      14          65

# %%
df3=pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#      city     temperature  humidity
# 0  baltimore     38.0         NaN
# 1    chicago     14.0        65.0
# 2   new york     21.0        68.0
# 3    orlando     35.0         NaN
# 4  san diego      NaN        71.0

# %%
df3=pd.merge(df2,df1,on="city",how="left")
df3
#print(df2)
# Out:
#      city     humidity  temperature
# 0    chicago     65        14.0
# 1   new york     68        21.0
# 2  san diego     71         NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#      city     temperature  humidity
# 0    chicago     14.0         65
# 1   new york     21.0         68
# 2  san diego      NaN         71

# %% [markdown]
# ## <font color='blue'>indicator flag</font>

# %%
df3=pd.merge(df2,df1,on="city",how="outer",indicator=True)
df3
# Out:
#      city     humidity  temperature    _merge
# 0  baltimore     NaN       38.0      right_only
# 1    chicago    65.0       14.0            both
# 2   new york    68.0       21.0            both
# 3    orlando     NaN       35.0      right_only
# 4  san diego    71.0        NaN       left_only

# %% [markdown]
# ## <font color='blue'>suffixes</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#      city     temperature  humidity
# 0   new york      21          65
# 1    chicago      14          68
# 2    orlando      35          71
# 3  baltimore      38          75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#      city     temperature  humidity
# 0    chicago      21          65
# 1   new york      14          68
# 2  san diego      35          71

# %%
df3= pd.merge(df1,df2,on="city",how="outer", suffixes=('_first','_second'))
df3
# Out:
#      city     temperature_first  humidity_first  temperature_second  \
# 0  baltimore        38.0              75.0               NaN
# 1    chicago        14.0              68.0              21.0
# 2   new york        21.0              65.0              14.0
# 3    orlando        35.0              71.0               NaN
# 4  san diego         NaN               NaN              35.0
#
#    humidity_second
# 0        NaN
# 1       65.0
# 2       68.0
# 3        NaN
# 4       71.0

# %% [markdown]
# ## <font color='blue'>join</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [65,68,75],
})
df1.set_index('city',inplace=True)
df1
# Out:
#           temperature  humidity
# city
# new york      21          65
# chicago       14          68
# orlando       35          75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [65,68,75],
})
df1.set_index('city')
# Out:
#           temperature  humidity
# city
# new york      21          65
# chicago       14          68
# orlando       35          75

# %%
df1
# Out:
#      city    temperature  humidity
# 0  new york      21          65
# 1   chicago      14          68
# 2   orlando      35          75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
    "temperature": [21,14,35],
})
df2.set_index('city',inplace=True)
df2
# Out:
#           humidity  temperature
# city
# chicago      65         21
# new york     68         14
# orlando      75         35

# %%
df1.join(df2,lsuffix='_l', rsuffix='_r')
# Out:
#      city    temperature_l  humidity_l  humidity_r  temperature_r
# 0  new york       21            65         NaN          NaN
# 1   chicago       14            68         NaN          NaN
# 2   orlando       35            75         NaN          NaN

# %% [markdown]
# ## <font color='blue'>Pandas Profiling</font>

# %%
! pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 6.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.3/664.3 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 4.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('./weather_data/weather_data.csv')
df.isna().sum().sum()
df1=df.ffill()
#df.isna().sum().sum()
#df1=df.fillna(method='ffill')
#df1
#df1=df.fillna()
#print(help(df.fillna))
profile = ProfileReport(df1, title="Profiling Report")
profile.to_notebook_iframe()
#profile1 = ProfileReport(df1, title="Profiling Report1")
#profile1.to_notebook_iframe()
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-15 15:36:39.404168&quot; name=date&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df.isna().sum().sum()
# Out:
# np.int64(9)

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('./weather_data/weather_data.csv')
profile = ProfileReport(df, title="Profiling Report")

profile.to_file("weather_profile.html")
print("Report saved to weather_profile.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 1133.60it/s]
# Report saved to weather_profile.html

# %% [markdown]
# ## <font color='blue'>Autoviz</font>

# %%
# %pip install autoviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 2.2 MB/s eta 0:00:00eta 0:00:04
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 3.7 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 4.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 4.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

filename = "./weather_data/weather_data.csv"
target_variable = "PlayCricket"

dft = AV.AutoViz(
    filename,
    sep=",",
    depVar=target_variable,
    dfte=None,
    header=0,
    verbose=1,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    save_plot_dir=None
)
help(dft)
dft.plot()
# Out:
# Shape of your Data Set loaded: (28, 5)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     4 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['day']
#
# ...
