# %%
import pandas as pd
import numpy as np
data = {
'Default': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No'],
'CreditScore': ['Poor', 'Good', 'Poor', 'Average', 'Poor',
'Good', 'Poor', 'Average', 'Poor', 'Good'],
'PastDefault': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No']
}
df=pd.DataFrame(data)
print(df)
import matplotlib.pyplot as plt

data = [45,48,50,52,55,60,62,65,70,75]

plt.hist(data, bins=4)
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.title("Histogram of Exam Scores")
plt.show()
# Out:
#   Default CreditScore PastDefault
# 0     Yes        Poor         Yes
# 1      No        Good          No
# 2     Yes        Poor         Yes
# 3      No     Average          No
# 4     Yes        Poor         Yes
# 5      No        Good          No
# 6     Yes        Poor         Yes
# 7      No     Average         Yes
# 8     Yes        Poor          No
# 9      No        Good          No
